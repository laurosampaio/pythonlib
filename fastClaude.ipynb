# %%
import os
import torch
import pandas as pd
import ast
import torchvision
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from torchvision.io import read_image
from torchvision import tv_tensors
from torchvision.transforms.v2 import functional as F
from torchvision.transforms import v2 as T
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.utils import draw_bounding_boxes
import utils
from engine import train_one_epoch, evaluate

def box_area(boxes):
    """
    Computes the area of a set of bounding boxes
    """
    return (boxes[:, 2] - boxes[:, 0]) * (boxes[:, 3] - boxes[:, 1])

def box_iou(boxes1, boxes2):
    """
    Return intersection-over-union (Jaccard index) between two sets of boxes.
    
    Args:
        boxes1 (Tensor[N, 4]): first set of boxes
        boxes2 (Tensor[M, 4]): second set of boxes
        
    Returns:
        iou (Tensor[N, M]): the NxM matrix containing the pairwise IoU values
    """
    area1 = box_area(boxes1)
    area2 = box_area(boxes2)

    # Calculate intersection coordinates
    lt = torch.max(boxes1[:, None, :2], boxes2[:, :2])  # left-top coordinates
    rb = torch.min(boxes1[:, None, 2:], boxes2[:, 2:])  # right-bottom coordinates

    # Calculate intersection area
    wh = (rb - lt).clamp(min=0)  # width-height
    inter = wh[:, :, 0] * wh[:, :, 1]  # intersection area

    # Calculate union area
    union = area1[:, None] + area2 - inter

    # Calculate IoU
    iou = inter / union
    return iou    

def save_model(model, working_dir):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    model_path = os.path.join(working_dir, f'model_{timestamp}.pth')
    torch.save(model.state_dict(), model_path)
    return model_path

def plot_metrics(metrics, metric_name, working_dir):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plt.figure(figsize=(10, 6))
    plt.plot(metrics)
    plt.title(f'Model {metric_name} over epochs')
    plt.xlabel('Epochs')
    plt.ylabel(metric_name)
    plt.grid(True)
    plot_path = os.path.join(working_dir, f'{metric_name.lower()}_{timestamp}.png')
    plt.savefig(plot_path)
    plt.close()

def plot_roc_curve(model, data_loader_test, device, working_dir, num_classes):
    model.eval()
    # Initialize dictionaries to store scores and labels for each class
    class_scores = {i: [] for i in range(1, num_classes)}  # Skip background class (0)
    class_labels = {i: [] for i in range(1, num_classes)}
    
    with torch.no_grad():
        for images, targets in data_loader_test:
            images = list(img.to(device) for img in images)
            predictions = model(images)
            
            for prediction, target in zip(predictions, targets):
                pred_scores = prediction['scores'].cpu().numpy()
                pred_labels = prediction['labels'].cpu().numpy()
                target_labels = target['labels'].cpu().numpy()
                
                # For each class
                for class_id in range(1, num_classes):
                    # Get predictions for this class
                    class_mask_pred = pred_labels == class_id
                    class_mask_target = target_labels == class_id
                    
                    # Add a score for each target instance
                    for target_idx in range(sum(class_mask_target)):
                        class_labels[class_id].append(1)
                        if sum(class_mask_pred) > 0:
                            # Use maximum score for this class as the prediction
                            class_scores[class_id].append(
                                max(pred_scores[class_mask_pred]) if any(class_mask_pred) else 0.0
                            )
                        else:
                            class_scores[class_id].append(0.0)
                    
                    # Add negative examples from other classes
                    other_classes = pred_labels[pred_labels != class_id]
                    other_scores = pred_scores[pred_labels != class_id]
                    for score in other_scores:
                        class_labels[class_id].append(0)
                        class_scores[class_id].append(score)

    # Plot ROC curves
    plt.figure(figsize=(10, 8))
    
    # Define class names
    class_names = {1: 'person', 2: 'cat', 3: 'dog'}
    
    # Plot ROC curve for each class
    for class_id in range(1, num_classes):
        if len(class_scores[class_id]) > 0:  # Only plot if we have predictions
            fpr, tpr, _ = roc_curve(
                class_labels[class_id], 
                class_scores[class_id]
            )
            roc_auc = auc(fpr, tpr)
            plt.plot(
                fpr, 
                tpr, 
                lw=2, 
                label=f'{class_names[class_id]} (AUC = {roc_auc:.2f})'
            )
    
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve per Class')
    plt.legend(loc="lower right")
    plt.grid(True)
    
    # Save the plot
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    plot_path = os.path.join(working_dir, f'roc_curve_{timestamp}.png')
    plt.savefig(plot_path)
    plt.close()

def calculate_map(model, data_loader_test, device):
    model.eval()
    all_maps = []
    
    with torch.no_grad():
        for images, targets in data_loader_test:
            images = list(img.to(device) for img in images)
            predictions = model(images)
            
            for prediction, target in zip(predictions, targets):
                pred_boxes = prediction['boxes'].cpu()
                pred_scores = prediction['scores'].cpu()
                pred_labels = prediction['labels'].cpu()
                
                target_boxes = target['boxes'].cpu()
                target_labels = target['labels'].cpu()
                
                if len(pred_boxes) > 0 and len(target_boxes) > 0:
                    # Sort predictions by score
                    scores_sorted, indices = torch.sort(pred_scores, descending=True)
                    pred_boxes = pred_boxes[indices]
                    pred_labels = pred_labels[indices]
                    
                    # Calculate IoU between predicted and target boxes
                    ious = box_iou(pred_boxes, target_boxes)  # Now using local box_iou function
                    
                    # Calculate AP for each class
                    for class_id in range(1, num_classes):
                        class_mask_pred = pred_labels == class_id
                        class_mask_target = target_labels == class_id
                        
                        if class_mask_target.sum() > 0:
                            class_ious = ious[class_mask_pred][:, class_mask_target]
                            if len(class_ious) > 0:
                                # For each ground truth box, get the max IoU
                                max_ious, _ = class_ious.max(dim=0)
                                # Calculate AP as the proportion of ground truth boxes 
                                # that have a matching prediction (IoU > 0.5)
                                ap = (max_ious > 0.5).float().mean()
                                all_maps.append(ap.item())
    
    return np.mean(all_maps) if all_maps else 0.0

def get_transform(train):
    transforms = []
    if train:
        transforms.append(T.RandomHorizontalFlip(0.5))
    transforms.append(T.ToDtype(torch.float, scale=True))
    transforms.append(T.ToPureTensor())
    return T.Compose(transforms)

class CocoSubsetDataset(torch.utils.data.Dataset):
    def __init__(self, csv_path, images_path, transforms=None):
        self.transforms = transforms
        self.images_path = images_path
        # Load CSV data
        self.df = pd.read_csv(csv_path)
        # Convert string representation of bbox to list
        self.df['bbox'] = self.df['bbox'].apply(ast.literal_eval)
        
        # Create category to id mapping
        self.category_to_id = {
            'person': 1,
            'cat': 2,
            'dog': 3
        }
        
    def __getitem__(self, idx):
        # Get all annotations for this image
        img_annots = self.df[self.df['image_id'] == self.df['image_id'].unique()[idx]]
        
        # Load image
        img_path = os.path.join(self.images_path, img_annots['image'].iloc[0])
        img = read_image(img_path)
        
        # If image is grayscale, convert to RGB
        if img.shape[0] == 1:
            img = img.repeat(3, 1, 1)
        
        # Get boxes and labels
        boxes = []
        labels = []
        
        for _, row in img_annots.iterrows():
            # Convert COCO bbox [x,y,width,height] to [x1,y1,x2,y2]
            bbox = row['bbox']
            boxes.append([
                bbox[0],
                bbox[1],
                bbox[0] + bbox[2],
                bbox[1] + bbox[3]
            ])
            labels.append(self.category_to_id[row['label']])
        
        # Convert to tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        
        # Prepare target dict
        img = tv_tensors.Image(img)
        target = {}
        target["boxes"] = tv_tensors.BoundingBoxes(boxes, format="XYXY", canvas_size=F.get_size(img))
        target["labels"] = labels
        target["image_id"] = torch.tensor([idx])
        
        if self.transforms is not None:
            img, target = self.transforms(img, target)
            
        return img, target
    
    def __len__(self):
        return len(self.df['image_id'].unique())

def get_model_detection(num_classes):
    # Load a pre-trained model
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights="DEFAULT")
    
    # Get number of input features
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    
    # Replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    
    return model

# Training setup
TRAIN_IMAGES_PATH = 'D:/Download/JDownloader/MSCOCO/images/train2017'
FILTERED_PATH = 'D:/Projetos/pythonlib/filtered-coco-dataset'
WORKING_DIR = 'D:/Projetos/pythonlib/working'
CSV_PATH = os.path.join(FILTERED_PATH, 'filtered_coco.csv')

# Number of classes (background + person + cat + dog)
num_classes = 4

# Create train and test datasets
dataset = CocoSubsetDataset(CSV_PATH, TRAIN_IMAGES_PATH, get_transform(train=True))
dataset_test = CocoSubsetDataset(CSV_PATH, TRAIN_IMAGES_PATH, get_transform(train=False))

# Split dataset
indices = torch.randperm(len(dataset)).tolist()
train_size = int(0.8 * len(dataset))  # 80% for training
dataset = torch.utils.data.Subset(dataset, indices[:train_size])
dataset_test = torch.utils.data.Subset(dataset_test, indices[train_size:])

# Create data loaders
data_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
    collate_fn=utils.collate_fn
)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test,
    batch_size=1,
    shuffle=False,
    collate_fn=utils.collate_fn
)

# Initialize model, optimizer and scheduler
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model = get_model_detection(num_classes)
model.to(device)

# Optimize all parameters
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

# Training loop
num_epochs = 3

accuracies = []
losses = []
maps = []

for epoch in range(num_epochs):
    # Train for one epoch and collect metrics
    metric_logger = train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
    
    # Store loss
    epoch_loss = metric_logger.meters['loss'].global_avg
    losses.append(epoch_loss)
    
    # Calculate and store mAP
    epoch_map = calculate_map(model, data_loader_test, device)
    maps.append(epoch_map)
    
    # Calculate and store accuracy (using mAP as accuracy metric for object detection)
    accuracies.append(epoch_map)
    
    # Update learning rate
    lr_scheduler.step()
    
    # Evaluate on test dataset
    #evaluate(model, data_loader_test, device=device)

# Save model
model_path = save_model(model, WORKING_DIR)
print(f"Model saved to: {model_path}")

# Generate and save plots
plot_metrics(accuracies, 'Accuracy', WORKING_DIR)
plot_metrics(losses, 'Loss', WORKING_DIR)
plot_metrics(maps, 'mAP', WORKING_DIR)
plot_roc_curve(model, data_loader_test, device, WORKING_DIR, num_classes)

print("Training and plotting completed!")

# Visualization function
def visualize_predictions(model, image_path, device, transform):
    image = read_image(image_path)
    
    # Transform image
    image_transformed = transform(image)
    image_transformed = image_transformed[:3, ...].to(device)
    
    # Get predictions
    model.eval()
    with torch.no_grad():
        predictions = model([image_transformed])
        pred = predictions[0]
    
    # Convert image for visualization
    image = image[:3, ...]  # Remove alpha channel if present
    image = (255.0 * (image - image.min()) / (image.max() - image.min())).to(torch.uint8)
    
    # Draw bounding boxes
    pred_scores = pred["scores"] > 0.5
    pred_boxes = pred["boxes"][pred_scores].long()
    pred_labels = pred["labels"][pred_scores]
    
    # Convert numeric labels to text
    id_to_label = {1: 'person', 2: 'cat', 3: 'dog'}
    pred_label_texts = [f"{id_to_label[label.item()]}: {score:.2f}" 
                       for label, score in zip(pred_labels, pred["scores"][pred_scores])]
    
    # Draw boxes
    output_image = draw_bounding_boxes(
        image, 
        pred_boxes,
        pred_label_texts,
        colors="red"
    )
    
    return output_image
# Out:
# d:\Projetos\pythonlib\engine.py:30: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=scaler is not None):
# Epoch: [0]  [   0/1142]  eta: 0:16:13  lr: 0.000010  loss: 1.8931 (1.8931)  loss_classifier: 1.5760 (1.5760)  loss_box_reg: 0.2338 (0.2338)  loss_objectness: 0.0742 (0.0742)  loss_rpn_box_reg: 0.0091 (0.0091)  time: 0.8522  data: 0.0070  max mem: 4952
# Epoch: [0]  [  10/1142]  eta: 0:16:37  lr: 0.000060  loss: 1.6158 (1.6368)  loss_classifier: 1.4720 (1.4440)  loss_box_reg: 0.1529 (0.1410)  loss_objectness: 0.0517 (0.0475)  loss_rpn_box_reg: 0.0032 (0.0043)  time: 0.8813  data: 0.0091  max mem: 5062
# Epoch: [0]  [  20/1142]  eta: 0:15:41  lr: 0.000110  loss: 1.4043 (1.3614)  loss_classifier: 1.1727 (1.1662)  loss_box_reg: 0.1395 (0.1512)  loss_objectness: 0.0265 (0.0391)  loss_rpn_box_reg: 0.0027 (0.0050)  time: 0.8380  data: 0.0084  max mem: 5062
# Epoch: [0]  [  30/1142]  eta: 0:15:30  lr: 0.000160  loss: 0.7375 (1.0831)  loss_classifier: 0.5213 (0.8946)  loss_box_reg: 0.1395 (0.1467)  loss_objectness: 0.0259 (0.0361)  loss_rpn_box_reg: 0.0036 (0.0057)  time: 0.8118  data: 0.0070  max mem: 5062
# Epoch: [0]  [  40/1142]  eta: 0:15:02  lr: 0.000210  loss: 0.3696 (0.8964)  loss_classifier: 0.2225 (0.7161)  loss_box_reg: 0.1286 (0.1414)  loss_objectness: 0.0270 (0.0338)  loss_rpn_box_reg: 0.0021 (0.0051)  time: 0.7981  data: 0.0070  max mem: 5062
# Epoch: [0]  [  50/1142]  eta: 0:14:39  lr: 0.000260  loss: 0.3092 (0.7864)  loss_classifier: 0.1552 (0.6095)  loss_box_reg: 0.1351 (0.1420)  loss_objectness: 0.0117 (0.0296)  loss_rpn_box_reg: 0.0022 (0.0052)  time: 0.7561  data: 0.0073  max mem: 5062
# Epoch: [0]  [  60/1142]  eta: 0:14:34  lr: 0.000310  loss: 0.3330 (0.7178)  loss_classifier: 0.1693 (0.5400)  loss_box_reg: 0.1517 (0.1452)  loss_objectness: 0.0074 (0.0278)  loss_rpn_box_reg: 0.0029 (0.0047)  time: 0.7873  data: 0.0070  max mem: 5064
# Epoch: [0]  [  70/1142]  eta: 0:14:14  lr: 0.000360  loss: 0.3153 (0.6554)  loss_classifier: 0.1553 (0.4826)  loss_box_reg: 0.1445 (0.1413)  loss_objectness: 0.0131 (0.0269)  loss_rpn_box_reg: 0.0020 (0.0046)  time: 0.7770  data: 0.0080  max mem: 5064
# Epoch: [0]  [  80/1142]  eta: 0:14:09  lr: 0.000410  loss: 0.2726 (0.6077)  loss_classifier: 0.1310 (0.4387)  loss_box_reg: 0.1149 (0.1389)  loss_objectness: 0.0181 (0.0255)  loss_rpn_box_reg: 0.0033 (0.0047)  time: 0.7741  data: 0.0081  max mem: 5064
# Epoch: [0]  [  90/1142]  eta: 0:13:55  lr: 0.000460  loss: 0.2654 (0.5711)  loss_classifier: 0.1202 (0.4043)  loss_box_reg: 0.1149 (0.1373)  loss_objectness: 0.0108 (0.0244)  loss_rpn_box_reg: 0.0023 (0.0051)  time: 0.7824  data: 0.0073  max mem: 5064
# Epoch: [0]  [ 100/1142]  eta: 0:13:45  lr: 0.000509  loss: 0.2794 (0.5426)  loss_classifier: 0.1184 (0.3759)  loss_box_reg: 0.1237 (0.1356)  loss_objectness: 0.0108 (0.0250)  loss_rpn_box_reg: 0.0022 (0.0060)  time: 0.7628  data: 0.0075  max mem: 5064
# Epoch: [0]  [ 110/1142]  eta: 0:13:34  lr: 0.000559  loss: 0.2622 (0.5169)  loss_classifier: 0.1032 (0.3512)  loss_box_reg: 0.1146 (0.1335)  loss_objectness: 0.0122 (0.0251)  loss_rpn_box_reg: 0.0025 (0.0070)  time: 0.7657  data: 0.0091  max mem: 5064
# Epoch: [0]  [ 120/1142]  eta: 0:13:35  lr: 0.000609  loss: 0.2347 (0.4949)  loss_classifier: 0.0999 (0.3314)  loss_box_reg: 0.1146 (0.1328)  loss_objectness: 0.0068 (0.0240)  loss_rpn_box_reg: 0.0031 (0.0068)  time: 0.8220  data: 0.0106  max mem: 5064
# Epoch: [0]  [ 130/1142]  eta: 0:13:37  lr: 0.000659  loss: 0.2381 (0.4791)  loss_classifier: 0.1048 (0.3153)  loss_box_reg: 0.1246 (0.1346)  loss_objectness: 0.0054 (0.0227)  loss_rpn_box_reg: 0.0023 (0.0065)  time: 0.9112  data: 0.0102  max mem: 5064
# Epoch: [0]  [ 140/1142]  eta: 0:13:23  lr: 0.000709  loss: 0.2416 (0.4620)  loss_classifier: 0.0947 (0.3001)  loss_box_reg: 0.1408 (0.1343)  loss_objectness: 0.0039 (0.0214)  loss_rpn_box_reg: 0.0019 (0.0063)  time: 0.8317  data: 0.0082  max mem: 5064
# Epoch: [0]  [ 150/1142]  eta: 0:13:05  lr: 0.000759  loss: 0.2277 (0.4458)  loss_classifier: 0.0855 (0.2858)  loss_box_reg: 0.1245 (0.1328)  loss_objectness: 0.0017 (0.0207)  loss_rpn_box_reg: 0.0026 (0.0065)  time: 0.6918  data: 0.0067  max mem: 5064
# Epoch: [0]  [ 160/1142]  eta: 0:13:03  lr: 0.000809  loss: 0.2115 (0.4314)  loss_classifier: 0.0855 (0.2740)  loss_box_reg: 0.1108 (0.1311)  loss_objectness: 0.0059 (0.0201)  loss_rpn_box_reg: 0.0026 (0.0063)  time: 0.7645  data: 0.0067  max mem: 5064
# Epoch: [0]  [ 170/1142]  eta: 0:12:54  lr: 0.000859  loss: 0.2136 (0.4200)  loss_classifier: 0.0942 (0.2630)  loss_box_reg: 0.1182 (0.1315)  loss_objectness: 0.0050 (0.0193)  loss_rpn_box_reg: 0.0017 (0.0061)  time: 0.8305  data: 0.0083  max mem: 5064
# Epoch: [0]  [ 180/1142]  eta: 0:12:48  lr: 0.000909  loss: 0.2151 (0.4087)  loss_classifier: 0.0735 (0.2526)  loss_box_reg: 0.1361 (0.1310)  loss_objectness: 0.0050 (0.0189)  loss_rpn_box_reg: 0.0017 (0.0062)  time: 0.8099  data: 0.0093  max mem: 5064
# Epoch: [0]  [ 190/1142]  eta: 0:12:42  lr: 0.000959  loss: 0.2079 (0.3991)  loss_classifier: 0.0699 (0.2435)  loss_box_reg: 0.1227 (0.1309)  loss_objectness: 0.0059 (0.0185)  loss_rpn_box_reg: 0.0022 (0.0062)  time: 0.8350  data: 0.0075  max mem: 5064
# Epoch: [0]  [ 200/1142]  eta: 0:12:32  lr: 0.001009  loss: 0.1921 (0.3898)  loss_classifier: 0.0705 (0.2355)  loss_box_reg: 0.1149 (0.1300)  loss_objectness: 0.0059 (0.0182)  loss_rpn_box_reg: 0.0027 (0.0061)  time: 0.7975  data: 0.0077  max mem: 5064
# Epoch: [0]  [ 210/1142]  eta: 0:12:22  lr: 0.001059  loss: 0.1964 (0.3815)  loss_classifier: 0.0792 (0.2281)  loss_box_reg: 0.1026 (0.1291)  loss_objectness: 0.0087 (0.0179)  loss_rpn_box_reg: 0.0023 (0.0064)  time: 0.7601  data: 0.0083  max mem: 5064
# Epoch: [0]  [ 220/1142]  eta: 0:12:24  lr: 0.001109  loss: 0.2074 (0.3732)  loss_classifier: 0.0690 (0.2208)  loss_box_reg: 0.1026 (0.1280)  loss_objectness: 0.0092 (0.0177)  loss_rpn_box_reg: 0.0023 (0.0068)  time: 0.8885  data: 0.0082  max mem: 5064
# Epoch: [0]  [ 230/1142]  eta: 0:12:13  lr: 0.001159  loss: 0.2061 (0.3657)  loss_classifier: 0.0690 (0.2144)  loss_box_reg: 0.0986 (0.1267)  loss_objectness: 0.0062 (0.0175)  loss_rpn_box_reg: 0.0023 (0.0070)  time: 0.8824  data: 0.0091  max mem: 5064
# Epoch: [0]  [ 240/1142]  eta: 0:12:06  lr: 0.001209  loss: 0.2061 (0.3594)  loss_classifier: 0.0706 (0.2087)  loss_box_reg: 0.1123 (0.1268)  loss_objectness: 0.0018 (0.0170)  loss_rpn_box_reg: 0.0021 (0.0068)  time: 0.7920  data: 0.0095  max mem: 5064
# Epoch: [0]  [ 250/1142]  eta: 0:11:55  lr: 0.001259  loss: 0.1747 (0.3519)  loss_classifier: 0.0699 (0.2029)  loss_box_reg: 0.1026 (0.1256)  loss_objectness: 0.0015 (0.0166)  loss_rpn_box_reg: 0.0021 (0.0068)  time: 0.7834  data: 0.0092  max mem: 5064
# Epoch: [0]  [ 260/1142]  eta: 0:11:50  lr: 0.001309  loss: 0.1692 (0.3489)  loss_classifier: 0.0602 (0.1978)  loss_box_reg: 0.0873 (0.1244)  loss_objectness: 0.0046 (0.0192)  loss_rpn_box_reg: 0.0025 (0.0074)  time: 0.7985  data: 0.0094  max mem: 5064
# Epoch: [0]  [ 270/1142]  eta: 0:11:42  lr: 0.001359  loss: 0.1865 (0.3437)  loss_classifier: 0.0620 (0.1934)  loss_box_reg: 0.0843 (0.1242)  loss_objectness: 0.0081 (0.0188)  loss_rpn_box_reg: 0.0026 (0.0073)  time: 0.8383  data: 0.0086  max mem: 5064
# Epoch: [0]  [ 280/1142]  eta: 0:11:31  lr: 0.001409  loss: 0.1888 (0.3387)  loss_classifier: 0.0702 (0.1898)  loss_box_reg: 0.0954 (0.1232)  loss_objectness: 0.0039 (0.0185)  loss_rpn_box_reg: 0.0029 (0.0072)  time: 0.7613  data: 0.0077  max mem: 5064
# Epoch: [0]  [ 290/1142]  eta: 0:11:23  lr: 0.001459  loss: 0.1918 (0.3336)  loss_classifier: 0.0684 (0.1856)  loss_box_reg: 0.0961 (0.1224)  loss_objectness: 0.0072 (0.0184)  loss_rpn_box_reg: 0.0035 (0.0072)  time: 0.7599  data: 0.0082  max mem: 5064
# Epoch: [0]  [ 300/1142]  eta: 0:11:16  lr: 0.001508  loss: 0.1810 (0.3289)  loss_classifier: 0.0785 (0.1822)  loss_box_reg: 0.0966 (0.1216)  loss_objectness: 0.0072 (0.0180)  loss_rpn_box_reg: 0.0031 (0.0072)  time: 0.8168  data: 0.0072  max mem: 5064
# Epoch: [0]  [ 310/1142]  eta: 0:11:05  lr: 0.001558  loss: 0.1645 (0.3239)  loss_classifier: 0.0785 (0.1784)  loss_box_reg: 0.0804 (0.1202)  loss_objectness: 0.0075 (0.0181)  loss_rpn_box_reg: 0.0031 (0.0072)  time: 0.7637  data: 0.0067  max mem: 5064
# Epoch: [0]  [ 320/1142]  eta: 0:10:59  lr: 0.001608  loss: 0.1553 (0.3189)  loss_classifier: 0.0677 (0.1751)  loss_box_reg: 0.0687 (0.1189)  loss_objectness: 0.0075 (0.0178)  loss_rpn_box_reg: 0.0028 (0.0072)  time: 0.7890  data: 0.0069  max mem: 5064
# Epoch: [0]  [ 330/1142]  eta: 0:10:52  lr: 0.001658  loss: 0.1512 (0.3142)  loss_classifier: 0.0565 (0.1716)  loss_box_reg: 0.0717 (0.1176)  loss_objectness: 0.0066 (0.0175)  loss_rpn_box_reg: 0.0039 (0.0075)  time: 0.8622  data: 0.0067  max mem: 5064
# Epoch: [0]  [ 340/1142]  eta: 0:10:42  lr: 0.001708  loss: 0.1443 (0.3093)  loss_classifier: 0.0548 (0.1684)  loss_box_reg: 0.0665 (0.1162)  loss_objectness: 0.0077 (0.0173)  loss_rpn_box_reg: 0.0030 (0.0075)  time: 0.7818  data: 0.0073  max mem: 5064
# Epoch: [0]  [ 350/1142]  eta: 0:10:35  lr: 0.001758  loss: 0.1447 (0.3051)  loss_classifier: 0.0607 (0.1655)  loss_box_reg: 0.0628 (0.1147)  loss_objectness: 0.0084 (0.0174)  loss_rpn_box_reg: 0.0027 (0.0075)  time: 0.7754  data: 0.0075  max mem: 5064
# Epoch: [0]  [ 360/1142]  eta: 0:10:25  lr: 0.001808  loss: 0.1408 (0.3008)  loss_classifier: 0.0624 (0.1626)  loss_box_reg: 0.0661 (0.1136)  loss_objectness: 0.0086 (0.0171)  loss_rpn_box_reg: 0.0031 (0.0074)  time: 0.7802  data: 0.0072  max mem: 5064
# Epoch: [0]  [ 370/1142]  eta: 0:10:19  lr: 0.001858  loss: 0.1428 (0.2971)  loss_classifier: 0.0666 (0.1601)  loss_box_reg: 0.0687 (0.1125)  loss_objectness: 0.0086 (0.0172)  loss_rpn_box_reg: 0.0029 (0.0074)  time: 0.8241  data: 0.0075  max mem: 5064
# Epoch: [0]  [ 380/1142]  eta: 0:10:12  lr: 0.001908  loss: 0.1442 (0.2930)  loss_classifier: 0.0636 (0.1575)  loss_box_reg: 0.0625 (0.1114)  loss_objectness: 0.0071 (0.0169)  loss_rpn_box_reg: 0.0019 (0.0073)  time: 0.8764  data: 0.0081  max mem: 5064
# Epoch: [0]  [ 390/1142]  eta: 0:10:04  lr: 0.001958  loss: 0.1402 (0.2890)  loss_classifier: 0.0513 (0.1549)  loss_box_reg: 0.0587 (0.1100)  loss_objectness: 0.0040 (0.0168)  loss_rpn_box_reg: 0.0019 (0.0072)  time: 0.8316  data: 0.0078  max mem: 5064
# Epoch: [0]  [ 400/1142]  eta: 0:09:57  lr: 0.002008  loss: 0.1289 (0.2852)  loss_classifier: 0.0529 (0.1526)  loss_box_reg: 0.0536 (0.1087)  loss_objectness: 0.0028 (0.0167)  loss_rpn_box_reg: 0.0025 (0.0072)  time: 0.8254  data: 0.0070  max mem: 5064
# Epoch: [0]  [ 410/1142]  eta: 0:09:50  lr: 0.002058  loss: 0.1528 (0.2826)  loss_classifier: 0.0614 (0.1508)  loss_box_reg: 0.0638 (0.1081)  loss_objectness: 0.0072 (0.0167)  loss_rpn_box_reg: 0.0019 (0.0070)  time: 0.8381  data: 0.0074  max mem: 5064
# Epoch: [0]  [ 420/1142]  eta: 0:09:39  lr: 0.002108  loss: 0.1528 (0.2795)  loss_classifier: 0.0756 (0.1488)  loss_box_reg: 0.0693 (0.1073)  loss_objectness: 0.0053 (0.0164)  loss_rpn_box_reg: 0.0019 (0.0069)  time: 0.7660  data: 0.0079  max mem: 5064
# Epoch: [0]  [ 430/1142]  eta: 0:09:32  lr: 0.002158  loss: 0.1269 (0.2758)  loss_classifier: 0.0547 (0.1466)  loss_box_reg: 0.0575 (0.1060)  loss_objectness: 0.0053 (0.0163)  loss_rpn_box_reg: 0.0019 (0.0069)  time: 0.7640  data: 0.0070  max mem: 5064
# Epoch: [0]  [ 440/1142]  eta: 0:09:41  lr: 0.002208  loss: 0.1269 (0.2739)  loss_classifier: 0.0558 (0.1455)  loss_box_reg: 0.0581 (0.1052)  loss_objectness: 0.0121 (0.0164)  loss_rpn_box_reg: 0.0019 (0.0068)  time: 1.3495  data: 0.0067  max mem: 5064
# Epoch: [0]  [ 450/1142]  eta: 0:09:46  lr: 0.002258  loss: 0.1818 (0.2717)  loss_classifier: 0.0832 (0.1440)  loss_box_reg: 0.0719 (0.1046)  loss_objectness: 0.0118 (0.0162)  loss_rpn_box_reg: 0.0024 (0.0069)  time: 1.7949  data: 0.0072  max mem: 5064
# Epoch: [0]  [ 460/1142]  eta: 0:09:56  lr: 0.002308  loss: 0.1574 (0.2695)  loss_classifier: 0.0751 (0.1427)  loss_box_reg: 0.0695 (0.1038)  loss_objectness: 0.0058 (0.0160)  loss_rpn_box_reg: 0.0041 (0.0070)  time: 1.9106  data: 0.0075  max mem: 5064
# Epoch: [0]  [ 470/1142]  eta: 0:10:00  lr: 0.002358  loss: 0.1397 (0.2668)  loss_classifier: 0.0635 (0.1411)  loss_box_reg: 0.0622 (0.1030)  loss_objectness: 0.0043 (0.0159)  loss_rpn_box_reg: 0.0018 (0.0069)  time: 1.9337  data: 0.0073  max mem: 5064
# Epoch: [0]  [ 480/1142]  eta: 0:10:08  lr: 0.002408  loss: 0.1638 (0.2645)  loss_classifier: 0.0753 (0.1397)  loss_box_reg: 0.0642 (0.1023)  loss_objectness: 0.0037 (0.0157)  loss_rpn_box_reg: 0.0017 (0.0068)  time: 1.9283  data: 0.0077  max mem: 5064
# Epoch: [0]  [ 490/1142]  eta: 0:10:14  lr: 0.002458  loss: 0.1638 (0.2628)  loss_classifier: 0.0625 (0.1386)  loss_box_reg: 0.0741 (0.1019)  loss_objectness: 0.0042 (0.0155)  loss_rpn_box_reg: 0.0023 (0.0068)  time: 2.0862  data: 0.0075  max mem: 5064
# Epoch: [0]  [ 500/1142]  eta: 0:10:17  lr: 0.002507  loss: 0.1754 (0.2615)  loss_classifier: 0.0822 (0.1376)  loss_box_reg: 0.0827 (0.1016)  loss_objectness: 0.0076 (0.0156)  loss_rpn_box_reg: 0.0031 (0.0068)  time: 2.0071  data: 0.0068  max mem: 5064
# Epoch: [0]  [ 510/1142]  eta: 0:10:24  lr: 0.002557  loss: 0.1723 (0.2594)  loss_classifier: 0.0725 (0.1362)  loss_box_reg: 0.0722 (0.1009)  loss_objectness: 0.0107 (0.0155)  loss_rpn_box_reg: 0.0029 (0.0068)  time: 2.0936  data: 0.0074  max mem: 5064
# Epoch: [0]  [ 520/1142]  eta: 0:10:27  lr: 0.002607  loss: 0.1525 (0.2575)  loss_classifier: 0.0615 (0.1350)  loss_box_reg: 0.0630 (0.1003)  loss_objectness: 0.0058 (0.0154)  loss_rpn_box_reg: 0.0023 (0.0069)  time: 2.1971  data: 0.0079  max mem: 5064
# Epoch: [0]  [ 530/1142]  eta: 0:10:31  lr: 0.002657  loss: 0.1581 (0.2555)  loss_classifier: 0.0753 (0.1338)  loss_box_reg: 0.0650 (0.0996)  loss_objectness: 0.0039 (0.0152)  loss_rpn_box_reg: 0.0019 (0.0068)  time: 2.1462  data: 0.0076  max mem: 5064
# Epoch: [0]  [ 540/1142]  eta: 0:10:28  lr: 0.002707  loss: 0.1367 (0.2535)  loss_classifier: 0.0753 (0.1326)  loss_box_reg: 0.0609 (0.0989)  loss_objectness: 0.0039 (0.0151)  loss_rpn_box_reg: 0.0033 (0.0068)  time: 1.9234  data: 0.0075  max mem: 5064
# Epoch: [0]  [ 550/1142]  eta: 0:10:27  lr: 0.002757  loss: 0.1277 (0.2514)  loss_classifier: 0.0546 (0.1313)  loss_box_reg: 0.0562 (0.0983)  loss_objectness: 0.0058 (0.0150)  loss_rpn_box_reg: 0.0039 (0.0068)  time: 1.7982  data: 0.0077  max mem: 5064
# Epoch: [0]  [ 560/1142]  eta: 0:10:29  lr: 0.002807  loss: 0.1277 (0.2496)  loss_classifier: 0.0578 (0.1303)  loss_box_reg: 0.0549 (0.0975)  loss_objectness: 0.0100 (0.0150)  loss_rpn_box_reg: 0.0019 (0.0067)  time: 2.1269  data: 0.0078  max mem: 5065
# Epoch: [0]  [ 570/1142]  eta: 0:10:32  lr: 0.002857  loss: 0.1292 (0.2476)  loss_classifier: 0.0590 (0.1291)  loss_box_reg: 0.0586 (0.0970)  loss_objectness: 0.0049 (0.0149)  loss_rpn_box_reg: 0.0024 (0.0067)  time: 2.3671  data: 0.0078  max mem: 5065
# Epoch: [0]  [ 580/1142]  eta: 0:10:27  lr: 0.002907  loss: 0.1368 (0.2457)  loss_classifier: 0.0519 (0.1279)  loss_box_reg: 0.0628 (0.0964)  loss_objectness: 0.0035 (0.0147)  loss_rpn_box_reg: 0.0030 (0.0067)  time: 2.0731  data: 0.0075  max mem: 5065
# Epoch: [0]  [ 590/1142]  eta: 0:10:20  lr: 0.002957  loss: 0.1516 (0.2442)  loss_classifier: 0.0605 (0.1268)  loss_box_reg: 0.0667 (0.0961)  loss_objectness: 0.0023 (0.0145)  loss_rpn_box_reg: 0.0032 (0.0067)  time: 1.6522  data: 0.0076  max mem: 5065
# Epoch: [0]  [ 600/1142]  eta: 0:10:14  lr: 0.003007  loss: 0.1525 (0.2428)  loss_classifier: 0.0627 (0.1259)  loss_box_reg: 0.0788 (0.0959)  loss_objectness: 0.0023 (0.0144)  loss_rpn_box_reg: 0.0032 (0.0067)  time: 1.6444  data: 0.0082  max mem: 5065
# Epoch: [0]  [ 610/1142]  eta: 0:10:08  lr: 0.003057  loss: 0.1373 (0.2412)  loss_classifier: 0.0640 (0.1251)  loss_box_reg: 0.0603 (0.0952)  loss_objectness: 0.0023 (0.0142)  loss_rpn_box_reg: 0.0026 (0.0067)  time: 1.7623  data: 0.0106  max mem: 5065
# Epoch: [0]  [ 620/1142]  eta: 0:10:03  lr: 0.003107  loss: 0.1352 (0.2403)  loss_classifier: 0.0707 (0.1245)  loss_box_reg: 0.0583 (0.0951)  loss_objectness: 0.0026 (0.0141)  loss_rpn_box_reg: 0.0033 (0.0066)  time: 1.8176  data: 0.0152  max mem: 5065
# Epoch: [0]  [ 630/1142]  eta: 0:09:57  lr: 0.003157  loss: 0.1481 (0.2391)  loss_classifier: 0.0707 (0.1238)  loss_box_reg: 0.0583 (0.0947)  loss_objectness: 0.0055 (0.0140)  loss_rpn_box_reg: 0.0025 (0.0066)  time: 1.8635  data: 0.0169  max mem: 5065
# Epoch: [0]  [ 640/1142]  eta: 0:09:50  lr: 0.003207  loss: 0.1481 (0.2381)  loss_classifier: 0.0626 (0.1233)  loss_box_reg: 0.0682 (0.0943)  loss_objectness: 0.0056 (0.0139)  loss_rpn_box_reg: 0.0016 (0.0065)  time: 1.8455  data: 0.0166  max mem: 5065
# Epoch: [0]  [ 650/1142]  eta: 0:09:46  lr: 0.003257  loss: 0.1221 (0.2362)  loss_classifier: 0.0543 (0.1222)  loss_box_reg: 0.0645 (0.0937)  loss_objectness: 0.0023 (0.0137)  loss_rpn_box_reg: 0.0024 (0.0065)  time: 1.9849  data: 0.0167  max mem: 5065
# Epoch: [0]  [ 660/1142]  eta: 0:09:45  lr: 0.003307  loss: 0.1189 (0.2349)  loss_classifier: 0.0571 (0.1215)  loss_box_reg: 0.0564 (0.0932)  loss_objectness: 0.0038 (0.0137)  loss_rpn_box_reg: 0.0037 (0.0065)  time: 2.4269  data: 0.0163  max mem: 5065
# Epoch: [0]  [ 670/1142]  eta: 0:09:41  lr: 0.003357  loss: 0.1459 (0.2338)  loss_classifier: 0.0618 (0.1208)  loss_box_reg: 0.0556 (0.0928)  loss_objectness: 0.0073 (0.0136)  loss_rpn_box_reg: 0.0024 (0.0065)  time: 2.5130  data: 0.0173  max mem: 5065
# Epoch: [0]  [ 680/1142]  eta: 0:09:37  lr: 0.003407  loss: 0.1425 (0.2325)  loss_classifier: 0.0618 (0.1201)  loss_box_reg: 0.0564 (0.0924)  loss_objectness: 0.0032 (0.0135)  loss_rpn_box_reg: 0.0024 (0.0066)  time: 2.3949  data: 0.0178  max mem: 5065
# Epoch: [0]  [ 690/1142]  eta: 0:09:31  lr: 0.003457  loss: 0.1492 (0.2317)  loss_classifier: 0.0640 (0.1197)  loss_box_reg: 0.0656 (0.0920)  loss_objectness: 0.0066 (0.0135)  loss_rpn_box_reg: 0.0024 (0.0065)  time: 2.3281  data: 0.0169  max mem: 5065
# Epoch: [0]  [ 700/1142]  eta: 0:09:25  lr: 0.003506  loss: 0.1429 (0.2305)  loss_classifier: 0.0568 (0.1189)  loss_box_reg: 0.0656 (0.0916)  loss_objectness: 0.0060 (0.0135)  loss_rpn_box_reg: 0.0029 (0.0065)  time: 2.3323  data: 0.0168  max mem: 5065
# Epoch: [0]  [ 710/1142]  eta: 0:09:19  lr: 0.003556  loss: 0.1340 (0.2294)  loss_classifier: 0.0565 (0.1182)  loss_box_reg: 0.0558 (0.0912)  loss_objectness: 0.0031 (0.0134)  loss_rpn_box_reg: 0.0021 (0.0066)  time: 2.3497  data: 0.0166  max mem: 5065
# Epoch: [0]  [ 720/1142]  eta: 0:09:10  lr: 0.003606  loss: 0.1319 (0.2281)  loss_classifier: 0.0569 (0.1174)  loss_box_reg: 0.0568 (0.0907)  loss_objectness: 0.0031 (0.0134)  loss_rpn_box_reg: 0.0020 (0.0066)  time: 2.1787  data: 0.0169  max mem: 5065
# Epoch: [0]  [ 730/1142]  eta: 0:09:01  lr: 0.003656  loss: 0.1325 (0.2270)  loss_classifier: 0.0595 (0.1168)  loss_box_reg: 0.0589 (0.0903)  loss_objectness: 0.0066 (0.0134)  loss_rpn_box_reg: 0.0020 (0.0065)  time: 2.0701  data: 0.0169  max mem: 5065
# Epoch: [0]  [ 740/1142]  eta: 0:08:52  lr: 0.003706  loss: 0.1546 (0.2261)  loss_classifier: 0.0677 (0.1162)  loss_box_reg: 0.0619 (0.0901)  loss_objectness: 0.0074 (0.0133)  loss_rpn_box_reg: 0.0026 (0.0065)  time: 2.0005  data: 0.0168  max mem: 5065
# Epoch: [0]  [ 750/1142]  eta: 0:08:43  lr: 0.003756  loss: 0.1663 (0.2256)  loss_classifier: 0.0733 (0.1158)  loss_box_reg: 0.0658 (0.0899)  loss_objectness: 0.0082 (0.0133)  loss_rpn_box_reg: 0.0026 (0.0066)  time: 2.1033  data: 0.0174  max mem: 5065
# Epoch: [0]  [ 760/1142]  eta: 0:08:32  lr: 0.003806  loss: 0.1484 (0.2248)  loss_classifier: 0.0735 (0.1153)  loss_box_reg: 0.0609 (0.0897)  loss_objectness: 0.0082 (0.0132)  loss_rpn_box_reg: 0.0024 (0.0066)  time: 1.9984  data: 0.0166  max mem: 5065
# Epoch: [0]  [ 770/1142]  eta: 0:08:21  lr: 0.003856  loss: 0.1389 (0.2236)  loss_classifier: 0.0670 (0.1146)  loss_box_reg: 0.0584 (0.0893)  loss_objectness: 0.0024 (0.0131)  loss_rpn_box_reg: 0.0029 (0.0066)  time: 1.8106  data: 0.0167  max mem: 5065
# Epoch: [0]  [ 780/1142]  eta: 0:08:11  lr: 0.003906  loss: 0.1305 (0.2226)  loss_classifier: 0.0574 (0.1140)  loss_box_reg: 0.0615 (0.0889)  loss_objectness: 0.0033 (0.0130)  loss_rpn_box_reg: 0.0024 (0.0066)  time: 1.9189  data: 0.0176  max mem: 5065
# Epoch: [0]  [ 790/1142]  eta: 0:08:00  lr: 0.003956  loss: 0.1300 (0.2216)  loss_classifier: 0.0672 (0.1135)  loss_box_reg: 0.0477 (0.0884)  loss_objectness: 0.0041 (0.0130)  loss_rpn_box_reg: 0.0025 (0.0067)  time: 2.0387  data: 0.0176  max mem: 5065
# Epoch: [0]  [ 800/1142]  eta: 0:07:48  lr: 0.004006  loss: 0.1478 (0.2207)  loss_classifier: 0.0692 (0.1130)  loss_box_reg: 0.0473 (0.0880)  loss_objectness: 0.0042 (0.0130)  loss_rpn_box_reg: 0.0032 (0.0067)  time: 1.9011  data: 0.0172  max mem: 5065
# Epoch: [0]  [ 810/1142]  eta: 0:07:37  lr: 0.004056  loss: 0.1466 (0.2199)  loss_classifier: 0.0582 (0.1124)  loss_box_reg: 0.0584 (0.0877)  loss_objectness: 0.0086 (0.0130)  loss_rpn_box_reg: 0.0028 (0.0067)  time: 1.9085  data: 0.0171  max mem: 5065
# Epoch: [0]  [ 820/1142]  eta: 0:07:27  lr: 0.004106  loss: 0.1466 (0.2193)  loss_classifier: 0.0588 (0.1120)  loss_box_reg: 0.0650 (0.0876)  loss_objectness: 0.0051 (0.0130)  loss_rpn_box_reg: 0.0032 (0.0067)  time: 2.1594  data: 0.0171  max mem: 5065
# Epoch: [0]  [ 830/1142]  eta: 0:07:16  lr: 0.004156  loss: 0.1439 (0.2183)  loss_classifier: 0.0662 (0.1114)  loss_box_reg: 0.0653 (0.0873)  loss_objectness: 0.0025 (0.0129)  loss_rpn_box_reg: 0.0030 (0.0067)  time: 2.1763  data: 0.0165  max mem: 5065
# Epoch: [0]  [ 840/1142]  eta: 0:07:04  lr: 0.004206  loss: 0.1439 (0.2175)  loss_classifier: 0.0693 (0.1109)  loss_box_reg: 0.0473 (0.0869)  loss_objectness: 0.0027 (0.0129)  loss_rpn_box_reg: 0.0030 (0.0068)  time: 2.0036  data: 0.0166  max mem: 5065
# Epoch: [0]  [ 850/1142]  eta: 0:06:52  lr: 0.004256  loss: 0.1476 (0.2169)  loss_classifier: 0.0724 (0.1105)  loss_box_reg: 0.0516 (0.0867)  loss_objectness: 0.0025 (0.0129)  loss_rpn_box_reg: 0.0048 (0.0068)  time: 2.0373  data: 0.0172  max mem: 5065
# Epoch: [0]  [ 860/1142]  eta: 0:06:41  lr: 0.004306  loss: 0.1582 (0.2164)  loss_classifier: 0.0793 (0.1103)  loss_box_reg: 0.0688 (0.0865)  loss_objectness: 0.0034 (0.0128)  loss_rpn_box_reg: 0.0042 (0.0068)  time: 2.2266  data: 0.0169  max mem: 5065
# Epoch: [0]  [ 870/1142]  eta: 0:06:28  lr: 0.004356  loss: 0.1642 (0.2157)  loss_classifier: 0.0780 (0.1098)  loss_box_reg: 0.0648 (0.0863)  loss_objectness: 0.0054 (0.0128)  loss_rpn_box_reg: 0.0039 (0.0068)  time: 2.0533  data: 0.0164  max mem: 5065
# Epoch: [0]  [ 880/1142]  eta: 0:06:15  lr: 0.004406  loss: 0.1335 (0.2150)  loss_classifier: 0.0691 (0.1094)  loss_box_reg: 0.0589 (0.0860)  loss_objectness: 0.0054 (0.0128)  loss_rpn_box_reg: 0.0030 (0.0068)  time: 1.9322  data: 0.0168  max mem: 5065
# Epoch: [0]  [ 890/1142]  eta: 0:06:02  lr: 0.004456  loss: 0.1302 (0.2145)  loss_classifier: 0.0691 (0.1091)  loss_box_reg: 0.0624 (0.0858)  loss_objectness: 0.0053 (0.0128)  loss_rpn_box_reg: 0.0013 (0.0067)  time: 1.9076  data: 0.0170  max mem: 5065
# Epoch: [0]  [ 900/1142]  eta: 0:05:49  lr: 0.004505  loss: 0.1302 (0.2136)  loss_classifier: 0.0619 (0.1086)  loss_box_reg: 0.0624 (0.0855)  loss_objectness: 0.0059 (0.0128)  loss_rpn_box_reg: 0.0027 (0.0067)  time: 1.8695  data: 0.0169  max mem: 5065
# Epoch: [0]  [ 910/1142]  eta: 0:05:37  lr: 0.004555  loss: 0.1154 (0.2127)  loss_classifier: 0.0541 (0.1081)  loss_box_reg: 0.0531 (0.0853)  loss_objectness: 0.0046 (0.0128)  loss_rpn_box_reg: 0.0030 (0.0067)  time: 2.1265  data: 0.0164  max mem: 5065
# Epoch: [0]  [ 920/1142]  eta: 0:05:24  lr: 0.004605  loss: 0.1149 (0.2120)  loss_classifier: 0.0641 (0.1077)  loss_box_reg: 0.0550 (0.0850)  loss_objectness: 0.0024 (0.0127)  loss_rpn_box_reg: 0.0024 (0.0067)  time: 2.1905  data: 0.0162  max mem: 5065
# Epoch: [0]  [ 930/1142]  eta: 0:05:11  lr: 0.004655  loss: 0.1444 (0.2113)  loss_classifier: 0.0668 (0.1073)  loss_box_reg: 0.0567 (0.0847)  loss_objectness: 0.0040 (0.0126)  loss_rpn_box_reg: 0.0024 (0.0067)  time: 2.1238  data: 0.0165  max mem: 5065
# Epoch: [0]  [ 940/1142]  eta: 0:04:57  lr: 0.004705  loss: 0.1604 (0.2109)  loss_classifier: 0.0795 (0.1071)  loss_box_reg: 0.0641 (0.0845)  loss_objectness: 0.0059 (0.0126)  loss_rpn_box_reg: 0.0020 (0.0066)  time: 2.1187  data: 0.0164  max mem: 5065
# Epoch: [0]  [ 950/1142]  eta: 0:04:44  lr: 0.004755  loss: 0.1516 (0.2100)  loss_classifier: 0.0750 (0.1066)  loss_box_reg: 0.0619 (0.0842)  loss_objectness: 0.0069 (0.0125)  loss_rpn_box_reg: 0.0021 (0.0066)  time: 2.1583  data: 0.0162  max mem: 5065
# Epoch: [0]  [ 960/1142]  eta: 0:04:30  lr: 0.004805  loss: 0.1214 (0.2095)  loss_classifier: 0.0579 (0.1064)  loss_box_reg: 0.0537 (0.0840)  loss_objectness: 0.0026 (0.0125)  loss_rpn_box_reg: 0.0025 (0.0066)  time: 2.0082  data: 0.0164  max mem: 5065
# Epoch: [0]  [ 970/1142]  eta: 0:04:16  lr: 0.004855  loss: 0.1698 (0.2091)  loss_classifier: 0.0809 (0.1062)  loss_box_reg: 0.0573 (0.0838)  loss_objectness: 0.0027 (0.0124)  loss_rpn_box_reg: 0.0034 (0.0067)  time: 1.8417  data: 0.0174  max mem: 5065
# Epoch: [0]  [ 980/1142]  eta: 0:04:02  lr: 0.004905  loss: 0.1705 (0.2086)  loss_classifier: 0.0686 (0.1058)  loss_box_reg: 0.0573 (0.0835)  loss_objectness: 0.0037 (0.0126)  loss_rpn_box_reg: 0.0045 (0.0067)  time: 1.9681  data: 0.0173  max mem: 5065
# Epoch: [0]  [ 990/1142]  eta: 0:03:47  lr: 0.004955  loss: 0.1626 (0.2081)  loss_classifier: 0.0676 (0.1055)  loss_box_reg: 0.0529 (0.0833)  loss_objectness: 0.0039 (0.0126)  loss_rpn_box_reg: 0.0040 (0.0067)  time: 1.9111  data: 0.0170  max mem: 5065
# Epoch: [0]  [1000/1142]  eta: 0:03:33  lr: 0.005000  loss: 0.1465 (0.2075)  loss_classifier: 0.0598 (0.1052)  loss_box_reg: 0.0519 (0.0831)  loss_objectness: 0.0043 (0.0126)  loss_rpn_box_reg: 0.0022 (0.0067)  time: 1.9491  data: 0.0171  max mem: 5065
# Epoch: [0]  [1010/1142]  eta: 0:03:19  lr: 0.005000  loss: 0.1291 (0.2070)  loss_classifier: 0.0638 (0.1049)  loss_box_reg: 0.0605 (0.0830)  loss_objectness: 0.0044 (0.0125)  loss_rpn_box_reg: 0.0024 (0.0066)  time: 2.0007  data: 0.0174  max mem: 5065
# Epoch: [0]  [1020/1142]  eta: 0:03:05  lr: 0.005000  loss: 0.1661 (0.2067)  loss_classifier: 0.0672 (0.1045)  loss_box_reg: 0.0660 (0.0827)  loss_objectness: 0.0083 (0.0128)  loss_rpn_box_reg: 0.0030 (0.0067)  time: 2.1287  data: 0.0181  max mem: 5065
# Epoch: [0]  [1030/1142]  eta: 0:02:50  lr: 0.005000  loss: 0.1327 (0.2061)  loss_classifier: 0.0528 (0.1041)  loss_box_reg: 0.0587 (0.0825)  loss_objectness: 0.0095 (0.0128)  loss_rpn_box_reg: 0.0046 (0.0067)  time: 2.2144  data: 0.0179  max mem: 5065
# Epoch: [0]  [1040/1142]  eta: 0:02:35  lr: 0.005000  loss: 0.1327 (0.2057)  loss_classifier: 0.0520 (0.1037)  loss_box_reg: 0.0582 (0.0822)  loss_objectness: 0.0149 (0.0130)  loss_rpn_box_reg: 0.0045 (0.0067)  time: 1.9542  data: 0.0170  max mem: 5065
# Epoch: [0]  [1050/1142]  eta: 0:02:20  lr: 0.005000  loss: 0.1581 (0.2054)  loss_classifier: 0.0653 (0.1035)  loss_box_reg: 0.0499 (0.0820)  loss_objectness: 0.0164 (0.0131)  loss_rpn_box_reg: 0.0067 (0.0069)  time: 1.9196  data: 0.0168  max mem: 5065
# Epoch: [0]  [1060/1142]  eta: 0:02:05  lr: 0.005000  loss: 0.1614 (0.2051)  loss_classifier: 0.0693 (0.1033)  loss_box_reg: 0.0534 (0.0819)  loss_objectness: 0.0109 (0.0131)  loss_rpn_box_reg: 0.0060 (0.0069)  time: 1.9087  data: 0.0177  max mem: 5065
# Epoch: [0]  [1070/1142]  eta: 0:01:50  lr: 0.005000  loss: 0.1465 (0.2046)  loss_classifier: 0.0685 (0.1030)  loss_box_reg: 0.0679 (0.0817)  loss_objectness: 0.0058 (0.0131)  loss_rpn_box_reg: 0.0033 (0.0069)  time: 1.8777  data: 0.0163  max mem: 5065
# Epoch: [0]  [1080/1142]  eta: 0:01:35  lr: 0.005000  loss: 0.1680 (0.2043)  loss_classifier: 0.0685 (0.1028)  loss_box_reg: 0.0658 (0.0816)  loss_objectness: 0.0058 (0.0131)  loss_rpn_box_reg: 0.0033 (0.0069)  time: 2.0651  data: 0.0158  max mem: 5065
# Epoch: [0]  [1090/1142]  eta: 0:01:20  lr: 0.005000  loss: 0.1640 (0.2037)  loss_classifier: 0.0642 (0.1025)  loss_box_reg: 0.0599 (0.0813)  loss_objectness: 0.0080 (0.0131)  loss_rpn_box_reg: 0.0028 (0.0068)  time: 2.0720  data: 0.0174  max mem: 5065
# Epoch: [0]  [1100/1142]  eta: 0:01:05  lr: 0.005000  loss: 0.1310 (0.2035)  loss_classifier: 0.0600 (0.1021)  loss_box_reg: 0.0517 (0.0811)  loss_objectness: 0.0080 (0.0135)  loss_rpn_box_reg: 0.0028 (0.0068)  time: 2.1338  data: 0.0254  max mem: 5065
# Epoch: [0]  [1110/1142]  eta: 0:00:49  lr: 0.005000  loss: 0.1350 (0.2032)  loss_classifier: 0.0634 (0.1019)  loss_box_reg: 0.0447 (0.0808)  loss_objectness: 0.0108 (0.0137)  loss_rpn_box_reg: 0.0040 (0.0069)  time: 2.1875  data: 0.0258  max mem: 5065
# Epoch: [0]  [1120/1142]  eta: 0:00:34  lr: 0.005000  loss: 0.1467 (0.2029)  loss_classifier: 0.0687 (0.1016)  loss_box_reg: 0.0521 (0.0806)  loss_objectness: 0.0183 (0.0137)  loss_rpn_box_reg: 0.0025 (0.0069)  time: 1.9522  data: 0.0178  max mem: 5065
# Epoch: [0]  [1130/1142]  eta: 0:00:18  lr: 0.005000  loss: 0.1467 (0.2026)  loss_classifier: 0.0570 (0.1014)  loss_box_reg: 0.0561 (0.0804)  loss_objectness: 0.0169 (0.0138)  loss_rpn_box_reg: 0.0023 (0.0070)  time: 1.9202  data: 0.0175  max mem: 5065
# Epoch: [0]  [1140/1142]  eta: 0:00:03  lr: 0.005000  loss: 0.1598 (0.2024)  loss_classifier: 0.0708 (0.1012)  loss_box_reg: 0.0619 (0.0803)  loss_objectness: 0.0126 (0.0139)  loss_rpn_box_reg: 0.0030 (0.0069)  time: 1.9661  data: 0.0171  max mem: 5065
# Epoch: [0]  [1141/1142]  eta: 0:00:01  lr: 0.005000  loss: 0.1598 (0.2023)  loss_classifier: 0.0708 (0.1012)  loss_box_reg: 0.0627 (0.0803)  loss_objectness: 0.0126 (0.0139)  loss_rpn_box_reg: 0.0038 (0.0069)  time: 1.9620  data: 0.0166  max mem: 5065
# Epoch: [0] Total time: 0:29:50 (1.5677 s / it)
# Epoch: [1]  [   0/1142]  eta: 0:35:22  lr: 0.005000  loss: 0.1020 (0.1020)  loss_classifier: 0.0463 (0.0463)  loss_box_reg: 0.0320 (0.0320)  loss_objectness: 0.0217 (0.0217)  loss_rpn_box_reg: 0.0020 (0.0020)  time: 1.8589  data: 0.0166  max mem: 5065
# Epoch: [1]  [  10/1142]  eta: 0:37:46  lr: 0.005000  loss: 0.1268 (0.1405)  loss_classifier: 0.0531 (0.0682)  loss_box_reg: 0.0425 (0.0553)  loss_objectness: 0.0050 (0.0078)  loss_rpn_box_reg: 0.0020 (0.0092)  time: 2.0026  data: 0.0135  max mem: 5065
# Epoch: [1]  [  20/1142]  eta: 0:38:19  lr: 0.005000  loss: 0.1268 (0.1373)  loss_classifier: 0.0609 (0.0655)  loss_box_reg: 0.0540 (0.0584)  loss_objectness: 0.0050 (0.0069)  loss_rpn_box_reg: 0.0026 (0.0066)  time: 2.0588  data: 0.0128  max mem: 5065
# Epoch: [1]  [  30/1142]  eta: 0:42:05  lr: 0.005000  loss: 0.1232 (0.1346)  loss_classifier: 0.0622 (0.0638)  loss_box_reg: 0.0540 (0.0570)  loss_objectness: 0.0054 (0.0075)  loss_rpn_box_reg: 0.0038 (0.0062)  time: 2.4191  data: 0.0120  max mem: 5065
# Epoch: [1]  [  40/1142]  eta: 0:41:29  lr: 0.005000  loss: 0.1147 (0.1322)  loss_classifier: 0.0637 (0.0641)  loss_box_reg: 0.0510 (0.0554)  loss_objectness: 0.0054 (0.0074)  loss_rpn_box_reg: 0.0028 (0.0053)  time: 2.4800  data: 0.0118  max mem: 5065
# Epoch: [1]  [  50/1142]  eta: 0:39:28  lr: 0.005000  loss: 0.1150 (0.1386)  loss_classifier: 0.0647 (0.0686)  loss_box_reg: 0.0471 (0.0569)  loss_objectness: 0.0039 (0.0067)  loss_rpn_box_reg: 0.0014 (0.0063)  time: 2.0109  data: 0.0127  max mem: 5065
# Epoch: [1]  [  60/1142]  eta: 0:39:17  lr: 0.005000  loss: 0.1260 (0.1384)  loss_classifier: 0.0647 (0.0670)  loss_box_reg: 0.0621 (0.0589)  loss_objectness: 0.0029 (0.0065)  loss_rpn_box_reg: 0.0019 (0.0060)  time: 2.0134  data: 0.0127  max mem: 5065
# Epoch: [1]  [  70/1142]  eta: 0:37:57  lr: 0.005000  loss: 0.1410 (0.1406)  loss_classifier: 0.0694 (0.0687)  loss_box_reg: 0.0703 (0.0594)  loss_objectness: 0.0033 (0.0063)  loss_rpn_box_reg: 0.0023 (0.0062)  time: 2.0111  data: 0.0121  max mem: 5065
# Epoch: [1]  [  80/1142]  eta: 0:37:15  lr: 0.005000  loss: 0.1424 (0.1428)  loss_classifier: 0.0714 (0.0691)  loss_box_reg: 0.0551 (0.0617)  loss_objectness: 0.0037 (0.0059)  loss_rpn_box_reg: 0.0017 (0.0061)  time: 1.8784  data: 0.0119  max mem: 5065
# Epoch: [1]  [  90/1142]  eta: 0:37:36  lr: 0.005000  loss: 0.1548 (0.1453)  loss_classifier: 0.0615 (0.0693)  loss_box_reg: 0.0639 (0.0627)  loss_objectness: 0.0038 (0.0060)  loss_rpn_box_reg: 0.0022 (0.0073)  time: 2.2175  data: 0.0111  max mem: 5065
# Epoch: [1]  [ 100/1142]  eta: 0:37:25  lr: 0.005000  loss: 0.1550 (0.1486)  loss_classifier: 0.0634 (0.0705)  loss_box_reg: 0.0639 (0.0636)  loss_objectness: 0.0038 (0.0066)  loss_rpn_box_reg: 0.0059 (0.0080)  time: 2.3592  data: 0.0123  max mem: 5065
# Epoch: [1]  [ 110/1142]  eta: 0:36:44  lr: 0.005000  loss: 0.1404 (0.1499)  loss_classifier: 0.0652 (0.0718)  loss_box_reg: 0.0532 (0.0640)  loss_objectness: 0.0033 (0.0066)  loss_rpn_box_reg: 0.0045 (0.0075)  time: 2.0946  data: 0.0128  max mem: 5065
# Epoch: [1]  [ 120/1142]  eta: 0:36:06  lr: 0.005000  loss: 0.1392 (0.1500)  loss_classifier: 0.0710 (0.0720)  loss_box_reg: 0.0451 (0.0633)  loss_objectness: 0.0042 (0.0068)  loss_rpn_box_reg: 0.0028 (0.0078)  time: 1.9426  data: 0.0114  max mem: 5065
# Epoch: [1]  [ 130/1142]  eta: 0:35:42  lr: 0.005000  loss: 0.1334 (0.1488)  loss_classifier: 0.0638 (0.0710)  loss_box_reg: 0.0533 (0.0631)  loss_objectness: 0.0042 (0.0068)  loss_rpn_box_reg: 0.0028 (0.0079)  time: 2.0105  data: 0.0112  max mem: 5065
# Epoch: [1]  [ 140/1142]  eta: 0:35:50  lr: 0.005000  loss: 0.1346 (0.1486)  loss_classifier: 0.0595 (0.0707)  loss_box_reg: 0.0570 (0.0629)  loss_objectness: 0.0058 (0.0070)  loss_rpn_box_reg: 0.0049 (0.0080)  time: 2.3027  data: 0.0113  max mem: 5072
# Epoch: [1]  [ 150/1142]  eta: 0:35:20  lr: 0.005000  loss: 0.1485 (0.1490)  loss_classifier: 0.0742 (0.0712)  loss_box_reg: 0.0584 (0.0629)  loss_objectness: 0.0085 (0.0072)  loss_rpn_box_reg: 0.0046 (0.0077)  time: 2.2763  data: 0.0120  max mem: 5072
# Epoch: [1]  [ 160/1142]  eta: 0:34:59  lr: 0.005000  loss: 0.1438 (0.1478)  loss_classifier: 0.0699 (0.0705)  loss_box_reg: 0.0541 (0.0623)  loss_objectness: 0.0095 (0.0073)  loss_rpn_box_reg: 0.0040 (0.0077)  time: 2.0794  data: 0.0122  max mem: 5072
# Epoch: [1]  [ 170/1142]  eta: 0:34:23  lr: 0.005000  loss: 0.1315 (0.1481)  loss_classifier: 0.0577 (0.0706)  loss_box_reg: 0.0523 (0.0626)  loss_objectness: 0.0067 (0.0073)  loss_rpn_box_reg: 0.0030 (0.0075)  time: 2.0103  data: 0.0128  max mem: 5072
# Epoch: [1]  [ 180/1142]  eta: 0:33:51  lr: 0.005000  loss: 0.1315 (0.1478)  loss_classifier: 0.0634 (0.0702)  loss_box_reg: 0.0473 (0.0621)  loss_objectness: 0.0063 (0.0079)  loss_rpn_box_reg: 0.0034 (0.0076)  time: 1.9058  data: 0.0129  max mem: 5072
# Epoch: [1]  [ 190/1142]  eta: 0:33:19  lr: 0.005000  loss: 0.1469 (0.1491)  loss_classifier: 0.0682 (0.0711)  loss_box_reg: 0.0496 (0.0624)  loss_objectness: 0.0063 (0.0082)  loss_rpn_box_reg: 0.0040 (0.0075)  time: 1.9086  data: 0.0129  max mem: 5072
# Epoch: [1]  [ 200/1142]  eta: 0:33:02  lr: 0.005000  loss: 0.1437 (0.1491)  loss_classifier: 0.0809 (0.0718)  loss_box_reg: 0.0496 (0.0620)  loss_objectness: 0.0038 (0.0080)  loss_rpn_box_reg: 0.0028 (0.0072)  time: 2.0324  data: 0.0132  max mem: 5072
# Epoch: [1]  [ 210/1142]  eta: 0:32:46  lr: 0.005000  loss: 0.1178 (0.1484)  loss_classifier: 0.0604 (0.0715)  loss_box_reg: 0.0478 (0.0616)  loss_objectness: 0.0040 (0.0081)  loss_rpn_box_reg: 0.0028 (0.0072)  time: 2.1971  data: 0.0124  max mem: 5072
# Epoch: [1]  [ 220/1142]  eta: 0:32:09  lr: 0.005000  loss: 0.1169 (0.1485)  loss_classifier: 0.0565 (0.0714)  loss_box_reg: 0.0575 (0.0620)  loss_objectness: 0.0063 (0.0080)  loss_rpn_box_reg: 0.0025 (0.0071)  time: 1.9786  data: 0.0117  max mem: 5072
# Epoch: [1]  [ 230/1142]  eta: 0:31:51  lr: 0.005000  loss: 0.1324 (0.1482)  loss_classifier: 0.0540 (0.0711)  loss_box_reg: 0.0601 (0.0622)  loss_objectness: 0.0044 (0.0079)  loss_rpn_box_reg: 0.0026 (0.0070)  time: 1.9556  data: 0.0120  max mem: 5072
# Epoch: [1]  [ 240/1142]  eta: 0:31:35  lr: 0.005000  loss: 0.1324 (0.1476)  loss_classifier: 0.0623 (0.0708)  loss_box_reg: 0.0601 (0.0619)  loss_objectness: 0.0029 (0.0080)  loss_rpn_box_reg: 0.0035 (0.0070)  time: 2.2038  data: 0.0140  max mem: 5072
# Epoch: [1]  [ 250/1142]  eta: 0:31:04  lr: 0.005000  loss: 0.1308 (0.1475)  loss_classifier: 0.0622 (0.0706)  loss_box_reg: 0.0557 (0.0617)  loss_objectness: 0.0028 (0.0083)  loss_rpn_box_reg: 0.0038 (0.0070)  time: 2.0175  data: 0.0149  max mem: 5072
# Epoch: [1]  [ 260/1142]  eta: 0:30:36  lr: 0.005000  loss: 0.1286 (0.1463)  loss_classifier: 0.0591 (0.0699)  loss_box_reg: 0.0484 (0.0612)  loss_objectness: 0.0033 (0.0082)  loss_rpn_box_reg: 0.0032 (0.0070)  time: 1.8438  data: 0.0122  max mem: 5072
# Epoch: [1]  [ 270/1142]  eta: 0:30:14  lr: 0.005000  loss: 0.1235 (0.1460)  loss_classifier: 0.0621 (0.0699)  loss_box_reg: 0.0491 (0.0611)  loss_objectness: 0.0031 (0.0081)  loss_rpn_box_reg: 0.0032 (0.0069)  time: 1.9639  data: 0.0113  max mem: 5072
# Epoch: [1]  [ 280/1142]  eta: 0:29:49  lr: 0.005000  loss: 0.1322 (0.1468)  loss_classifier: 0.0634 (0.0705)  loss_box_reg: 0.0576 (0.0611)  loss_objectness: 0.0031 (0.0081)  loss_rpn_box_reg: 0.0044 (0.0070)  time: 1.9995  data: 0.0125  max mem: 5072
# Epoch: [1]  [ 290/1142]  eta: 0:29:40  lr: 0.005000  loss: 0.1479 (0.1478)  loss_classifier: 0.0873 (0.0712)  loss_box_reg: 0.0603 (0.0613)  loss_objectness: 0.0054 (0.0081)  loss_rpn_box_reg: 0.0046 (0.0071)  time: 2.2071  data: 0.0122  max mem: 5072
# Epoch: [1]  [ 300/1142]  eta: 0:29:23  lr: 0.005000  loss: 0.1621 (0.1477)  loss_classifier: 0.0822 (0.0710)  loss_box_reg: 0.0613 (0.0614)  loss_objectness: 0.0045 (0.0081)  loss_rpn_box_reg: 0.0026 (0.0073)  time: 2.3473  data: 0.0135  max mem: 5072
# Epoch: [1]  [ 310/1142]  eta: 0:28:55  lr: 0.005000  loss: 0.1250 (0.1470)  loss_classifier: 0.0599 (0.0708)  loss_box_reg: 0.0569 (0.0611)  loss_objectness: 0.0035 (0.0080)  loss_rpn_box_reg: 0.0017 (0.0072)  time: 2.0308  data: 0.0130  max mem: 5072
# Epoch: [1]  [ 320/1142]  eta: 0:28:27  lr: 0.005000  loss: 0.1280 (0.1472)  loss_classifier: 0.0651 (0.0708)  loss_box_reg: 0.0569 (0.0612)  loss_objectness: 0.0046 (0.0081)  loss_rpn_box_reg: 0.0023 (0.0070)  time: 1.8181  data: 0.0138  max mem: 5072
# Epoch: [1]  [ 330/1142]  eta: 0:28:06  lr: 0.005000  loss: 0.1280 (0.1468)  loss_classifier: 0.0601 (0.0704)  loss_box_reg: 0.0577 (0.0611)  loss_objectness: 0.0063 (0.0082)  loss_rpn_box_reg: 0.0030 (0.0071)  time: 1.9490  data: 0.0161  max mem: 5072
# Epoch: [1]  [ 340/1142]  eta: 0:27:47  lr: 0.005000  loss: 0.1188 (0.1461)  loss_classifier: 0.0491 (0.0701)  loss_box_reg: 0.0487 (0.0607)  loss_objectness: 0.0062 (0.0082)  loss_rpn_box_reg: 0.0031 (0.0070)  time: 2.1043  data: 0.0147  max mem: 5072
# Epoch: [1]  [ 350/1142]  eta: 0:27:18  lr: 0.005000  loss: 0.1113 (0.1456)  loss_classifier: 0.0588 (0.0702)  loss_box_reg: 0.0484 (0.0603)  loss_objectness: 0.0050 (0.0081)  loss_rpn_box_reg: 0.0019 (0.0069)  time: 1.9275  data: 0.0141  max mem: 5072
# Epoch: [1]  [ 360/1142]  eta: 0:26:51  lr: 0.005000  loss: 0.1151 (0.1454)  loss_classifier: 0.0602 (0.0703)  loss_box_reg: 0.0495 (0.0602)  loss_objectness: 0.0034 (0.0081)  loss_rpn_box_reg: 0.0025 (0.0069)  time: 1.7553  data: 0.0146  max mem: 5072
# Epoch: [1]  [ 370/1142]  eta: 0:26:23  lr: 0.005000  loss: 0.1283 (0.1459)  loss_classifier: 0.0633 (0.0706)  loss_box_reg: 0.0570 (0.0604)  loss_objectness: 0.0042 (0.0080)  loss_rpn_box_reg: 0.0036 (0.0069)  time: 1.7503  data: 0.0141  max mem: 5072
# Epoch: [1]  [ 380/1142]  eta: 0:25:59  lr: 0.005000  loss: 0.1336 (0.1453)  loss_classifier: 0.0624 (0.0702)  loss_box_reg: 0.0570 (0.0604)  loss_objectness: 0.0042 (0.0079)  loss_rpn_box_reg: 0.0033 (0.0068)  time: 1.7867  data: 0.0133  max mem: 5072
# Epoch: [1]  [ 390/1142]  eta: 0:25:30  lr: 0.005000  loss: 0.1259 (0.1453)  loss_classifier: 0.0580 (0.0702)  loss_box_reg: 0.0548 (0.0604)  loss_objectness: 0.0048 (0.0079)  loss_rpn_box_reg: 0.0029 (0.0068)  time: 1.7313  data: 0.0124  max mem: 5072
# Epoch: [1]  [ 400/1142]  eta: 0:25:06  lr: 0.005000  loss: 0.1371 (0.1451)  loss_classifier: 0.0684 (0.0701)  loss_box_reg: 0.0536 (0.0600)  loss_objectness: 0.0048 (0.0081)  loss_rpn_box_reg: 0.0022 (0.0068)  time: 1.7191  data: 0.0123  max mem: 5072
# Epoch: [1]  [ 410/1142]  eta: 0:24:37  lr: 0.005000  loss: 0.1357 (0.1450)  loss_classifier: 0.0623 (0.0701)  loss_box_reg: 0.0513 (0.0600)  loss_objectness: 0.0089 (0.0081)  loss_rpn_box_reg: 0.0034 (0.0068)  time: 1.7027  data: 0.0138  max mem: 5072
# Epoch: [1]  [ 420/1142]  eta: 0:24:18  lr: 0.005000  loss: 0.1539 (0.1455)  loss_classifier: 0.0722 (0.0704)  loss_box_reg: 0.0638 (0.0600)  loss_objectness: 0.0090 (0.0082)  loss_rpn_box_reg: 0.0034 (0.0068)  time: 1.8326  data: 0.0132  max mem: 5072
# Epoch: [1]  [ 430/1142]  eta: 0:23:57  lr: 0.005000  loss: 0.1539 (0.1459)  loss_classifier: 0.0791 (0.0707)  loss_box_reg: 0.0572 (0.0602)  loss_objectness: 0.0063 (0.0082)  loss_rpn_box_reg: 0.0026 (0.0068)  time: 2.0196  data: 0.0136  max mem: 5072
# Epoch: [1]  [ 440/1142]  eta: 0:23:34  lr: 0.005000  loss: 0.1354 (0.1461)  loss_classifier: 0.0819 (0.0710)  loss_box_reg: 0.0542 (0.0600)  loss_objectness: 0.0057 (0.0083)  loss_rpn_box_reg: 0.0028 (0.0068)  time: 1.8968  data: 0.0147  max mem: 5072
# Epoch: [1]  [ 450/1142]  eta: 0:23:16  lr: 0.005000  loss: 0.1362 (0.1460)  loss_classifier: 0.0751 (0.0711)  loss_box_reg: 0.0475 (0.0599)  loss_objectness: 0.0041 (0.0082)  loss_rpn_box_reg: 0.0029 (0.0067)  time: 2.0040  data: 0.0124  max mem: 5072
# Epoch: [1]  [ 460/1142]  eta: 0:22:59  lr: 0.005000  loss: 0.1471 (0.1465)  loss_classifier: 0.0717 (0.0713)  loss_box_reg: 0.0486 (0.0600)  loss_objectness: 0.0034 (0.0083)  loss_rpn_box_reg: 0.0030 (0.0068)  time: 2.1773  data: 0.0112  max mem: 5072
# Epoch: [1]  [ 470/1142]  eta: 0:22:38  lr: 0.005000  loss: 0.1642 (0.1466)  loss_classifier: 0.0790 (0.0716)  loss_box_reg: 0.0456 (0.0599)  loss_objectness: 0.0061 (0.0084)  loss_rpn_box_reg: 0.0022 (0.0067)  time: 2.0846  data: 0.0138  max mem: 5072
# Epoch: [1]  [ 480/1142]  eta: 0:22:16  lr: 0.005000  loss: 0.1348 (0.1463)  loss_classifier: 0.0664 (0.0714)  loss_box_reg: 0.0456 (0.0599)  loss_objectness: 0.0060 (0.0083)  loss_rpn_box_reg: 0.0020 (0.0067)  time: 1.9494  data: 0.0132  max mem: 5072
# Epoch: [1]  [ 490/1142]  eta: 0:21:58  lr: 0.005000  loss: 0.1253 (0.1459)  loss_classifier: 0.0552 (0.0712)  loss_box_reg: 0.0640 (0.0599)  loss_objectness: 0.0030 (0.0082)  loss_rpn_box_reg: 0.0033 (0.0066)  time: 2.0524  data: 0.0115  max mem: 5072
# Epoch: [1]  [ 500/1142]  eta: 0:21:37  lr: 0.005000  loss: 0.1060 (0.1455)  loss_classifier: 0.0524 (0.0710)  loss_box_reg: 0.0499 (0.0597)  loss_objectness: 0.0034 (0.0081)  loss_rpn_box_reg: 0.0032 (0.0066)  time: 2.0781  data: 0.0124  max mem: 5072
# Epoch: [1]  [ 510/1142]  eta: 0:21:16  lr: 0.005000  loss: 0.1120 (0.1454)  loss_classifier: 0.0484 (0.0708)  loss_box_reg: 0.0501 (0.0598)  loss_objectness: 0.0038 (0.0081)  loss_rpn_box_reg: 0.0032 (0.0066)  time: 1.9386  data: 0.0128  max mem: 5072
# Epoch: [1]  [ 520/1142]  eta: 0:20:56  lr: 0.005000  loss: 0.1341 (0.1455)  loss_classifier: 0.0611 (0.0709)  loss_box_reg: 0.0566 (0.0598)  loss_objectness: 0.0065 (0.0082)  loss_rpn_box_reg: 0.0040 (0.0066)  time: 1.9866  data: 0.0134  max mem: 5072
# Epoch: [1]  [ 530/1142]  eta: 0:20:34  lr: 0.005000  loss: 0.1440 (0.1454)  loss_classifier: 0.0645 (0.0707)  loss_box_reg: 0.0566 (0.0598)  loss_objectness: 0.0055 (0.0082)  loss_rpn_box_reg: 0.0035 (0.0067)  time: 1.9607  data: 0.0128  max mem: 5072
# Epoch: [1]  [ 540/1142]  eta: 0:20:14  lr: 0.005000  loss: 0.1352 (0.1452)  loss_classifier: 0.0635 (0.0707)  loss_box_reg: 0.0542 (0.0597)  loss_objectness: 0.0055 (0.0082)  loss_rpn_box_reg: 0.0020 (0.0067)  time: 1.9276  data: 0.0136  max mem: 5072
# Epoch: [1]  [ 550/1142]  eta: 0:19:54  lr: 0.005000  loss: 0.1352 (0.1450)  loss_classifier: 0.0668 (0.0705)  loss_box_reg: 0.0526 (0.0596)  loss_objectness: 0.0068 (0.0082)  loss_rpn_box_reg: 0.0025 (0.0067)  time: 2.0514  data: 0.0156  max mem: 5072
# Epoch: [1]  [ 560/1142]  eta: 0:19:32  lr: 0.005000  loss: 0.1366 (0.1456)  loss_classifier: 0.0633 (0.0708)  loss_box_reg: 0.0548 (0.0596)  loss_objectness: 0.0082 (0.0084)  loss_rpn_box_reg: 0.0036 (0.0068)  time: 1.9667  data: 0.0147  max mem: 5072
# Epoch: [1]  [ 570/1142]  eta: 0:19:08  lr: 0.005000  loss: 0.1394 (0.1454)  loss_classifier: 0.0577 (0.0706)  loss_box_reg: 0.0629 (0.0597)  loss_objectness: 0.0069 (0.0084)  loss_rpn_box_reg: 0.0039 (0.0068)  time: 1.7349  data: 0.0129  max mem: 5072
# Epoch: [1]  [ 580/1142]  eta: 0:18:47  lr: 0.005000  loss: 0.1388 (0.1456)  loss_classifier: 0.0631 (0.0706)  loss_box_reg: 0.0619 (0.0596)  loss_objectness: 0.0033 (0.0085)  loss_rpn_box_reg: 0.0031 (0.0069)  time: 1.7426  data: 0.0124  max mem: 5072
# Epoch: [1]  [ 590/1142]  eta: 0:18:24  lr: 0.005000  loss: 0.1388 (0.1458)  loss_classifier: 0.0708 (0.0707)  loss_box_reg: 0.0570 (0.0598)  loss_objectness: 0.0052 (0.0085)  loss_rpn_box_reg: 0.0031 (0.0069)  time: 1.8006  data: 0.0130  max mem: 5072
# Epoch: [1]  [ 600/1142]  eta: 0:18:02  lr: 0.005000  loss: 0.1284 (0.1458)  loss_classifier: 0.0597 (0.0706)  loss_box_reg: 0.0570 (0.0599)  loss_objectness: 0.0083 (0.0085)  loss_rpn_box_reg: 0.0032 (0.0069)  time: 1.7375  data: 0.0147  max mem: 5072
# Epoch: [1]  [ 610/1142]  eta: 0:17:43  lr: 0.005000  loss: 0.1302 (0.1460)  loss_classifier: 0.0571 (0.0707)  loss_box_reg: 0.0550 (0.0600)  loss_objectness: 0.0089 (0.0085)  loss_rpn_box_reg: 0.0042 (0.0069)  time: 1.9097  data: 0.0139  max mem: 5072
# Epoch: [1]  [ 620/1142]  eta: 0:17:23  lr: 0.005000  loss: 0.1437 (0.1464)  loss_classifier: 0.0580 (0.0709)  loss_box_reg: 0.0646 (0.0601)  loss_objectness: 0.0040 (0.0085)  loss_rpn_box_reg: 0.0034 (0.0069)  time: 2.0873  data: 0.0123  max mem: 5072
# Epoch: [1]  [ 630/1142]  eta: 0:17:04  lr: 0.005000  loss: 0.1437 (0.1468)  loss_classifier: 0.0638 (0.0710)  loss_box_reg: 0.0562 (0.0601)  loss_objectness: 0.0074 (0.0086)  loss_rpn_box_reg: 0.0051 (0.0070)  time: 2.0833  data: 0.0117  max mem: 5072
# Epoch: [1]  [ 640/1142]  eta: 0:16:45  lr: 0.005000  loss: 0.1184 (0.1468)  loss_classifier: 0.0576 (0.0710)  loss_box_reg: 0.0480 (0.0601)  loss_objectness: 0.0075 (0.0087)  loss_rpn_box_reg: 0.0045 (0.0070)  time: 2.0861  data: 0.0119  max mem: 5072
# Epoch: [1]  [ 650/1142]  eta: 0:16:23  lr: 0.005000  loss: 0.1202 (0.1471)  loss_classifier: 0.0597 (0.0711)  loss_box_reg: 0.0564 (0.0603)  loss_objectness: 0.0075 (0.0087)  loss_rpn_box_reg: 0.0048 (0.0070)  time: 1.9641  data: 0.0133  max mem: 5072
# Epoch: [1]  [ 660/1142]  eta: 0:16:02  lr: 0.005000  loss: 0.1202 (0.1469)  loss_classifier: 0.0530 (0.0709)  loss_box_reg: 0.0471 (0.0601)  loss_objectness: 0.0071 (0.0087)  loss_rpn_box_reg: 0.0048 (0.0072)  time: 1.7958  data: 0.0149  max mem: 5072
# Epoch: [1]  [ 670/1142]  eta: 0:15:44  lr: 0.005000  loss: 0.1207 (0.1471)  loss_classifier: 0.0492 (0.0712)  loss_box_reg: 0.0374 (0.0602)  loss_objectness: 0.0044 (0.0086)  loss_rpn_box_reg: 0.0024 (0.0071)  time: 2.0298  data: 0.0167  max mem: 5072
# Epoch: [1]  [ 680/1142]  eta: 0:15:23  lr: 0.005000  loss: 0.1260 (0.1472)  loss_classifier: 0.0791 (0.0713)  loss_box_reg: 0.0490 (0.0603)  loss_objectness: 0.0044 (0.0086)  loss_rpn_box_reg: 0.0024 (0.0071)  time: 2.0705  data: 0.0151  max mem: 5072
# Epoch: [1]  [ 690/1142]  eta: 0:15:03  lr: 0.005000  loss: 0.1324 (0.1472)  loss_classifier: 0.0729 (0.0712)  loss_box_reg: 0.0490 (0.0601)  loss_objectness: 0.0058 (0.0087)  loss_rpn_box_reg: 0.0023 (0.0071)  time: 1.9478  data: 0.0123  max mem: 5072
# Epoch: [1]  [ 700/1142]  eta: 0:14:43  lr: 0.005000  loss: 0.1324 (0.1475)  loss_classifier: 0.0645 (0.0714)  loss_box_reg: 0.0514 (0.0602)  loss_objectness: 0.0062 (0.0088)  loss_rpn_box_reg: 0.0027 (0.0071)  time: 2.0386  data: 0.0108  max mem: 5072
# Epoch: [1]  [ 710/1142]  eta: 0:14:24  lr: 0.005000  loss: 0.1151 (0.1469)  loss_classifier: 0.0562 (0.0711)  loss_box_reg: 0.0514 (0.0600)  loss_objectness: 0.0055 (0.0087)  loss_rpn_box_reg: 0.0034 (0.0071)  time: 2.0402  data: 0.0109  max mem: 5072
# Epoch: [1]  [ 720/1142]  eta: 0:14:03  lr: 0.005000  loss: 0.1173 (0.1472)  loss_classifier: 0.0530 (0.0712)  loss_box_reg: 0.0452 (0.0600)  loss_objectness: 0.0048 (0.0088)  loss_rpn_box_reg: 0.0032 (0.0071)  time: 1.9889  data: 0.0127  max mem: 5072
# ...
# Epoch: [2]  [ 540/1142]  eta: 0:19:15  lr: 0.005000  loss: 0.1137 (0.1291)  loss_classifier: 0.0566 (0.0621)  loss_box_reg: 0.0488 (0.0540)  loss_objectness: 0.0059 (0.0069)  loss_rpn_box_reg: 0.0019 (0.0061)  time: 2.1155  data: 0.0069  max mem: 5436
# Epoch: [2]  [ 550/1142]  eta: 0:19:02  lr: 0.005000  loss: 0.1107 (0.1288)  loss_classifier: 0.0605 (0.0621)  loss_box_reg: 0.0417 (0.0538)  loss_objectness: 0.0034 (0.0068)  loss_rpn_box_reg: 0.0027 (0.0061)  time: 2.2531  data: 0.0069  max mem: 5436
# Epoch: [2]  [ 560/1142]  eta: 0:18:43  lr: 0.005000  loss: 0.1064 (0.1286)  loss_classifier: 0.0485 (0.0619)  loss_box_reg: 0.0450 (0.0537)  loss_objectness: 0.0033 (0.0069)  loss_rpn_box_reg: 0.0029 (0.0061)  time: 2.2681  data: 0.0068  max mem: 5436
# Epoch: [2]  [ 570/1142]  eta: 0:18:25  lr: 0.005000  loss: 0.1036 (0.1284)  loss_classifier: 0.0455 (0.0618)  loss_box_reg: 0.0469 (0.0538)  loss_objectness: 0.0033 (0.0068)  loss_rpn_box_reg: 0.0037 (0.0061)  time: 1.9907  data: 0.0071  max mem: 5436
# Epoch: [2]  [ 580/1142]  eta: 0:18:06  lr: 0.005000  loss: 0.1073 (0.1282)  loss_classifier: 0.0478 (0.0617)  loss_box_reg: 0.0488 (0.0537)  loss_objectness: 0.0030 (0.0068)  loss_rpn_box_reg: 0.0037 (0.0061)  time: 1.9679  data: 0.0074  max mem: 5436
# Epoch: [2]  [ 590/1142]  eta: 0:17:46  lr: 0.005000  loss: 0.1180 (0.1282)  loss_classifier: 0.0569 (0.0616)  loss_box_reg: 0.0473 (0.0537)  loss_objectness: 0.0030 (0.0068)  loss_rpn_box_reg: 0.0027 (0.0060)  time: 1.8998  data: 0.0071  max mem: 5436
# Epoch: [2]  [ 600/1142]  eta: 0:17:24  lr: 0.005000  loss: 0.1124 (0.1279)  loss_classifier: 0.0569 (0.0616)  loss_box_reg: 0.0433 (0.0536)  loss_objectness: 0.0020 (0.0068)  loss_rpn_box_reg: 0.0023 (0.0060)  time: 1.7847  data: 0.0069  max mem: 5436
# Epoch: [2]  [ 610/1142]  eta: 0:17:04  lr: 0.005000  loss: 0.1100 (0.1279)  loss_classifier: 0.0524 (0.0615)  loss_box_reg: 0.0433 (0.0537)  loss_objectness: 0.0016 (0.0067)  loss_rpn_box_reg: 0.0025 (0.0059)  time: 1.7426  data: 0.0071  max mem: 5436
# Epoch: [2]  [ 620/1142]  eta: 0:16:44  lr: 0.005000  loss: 0.1100 (0.1279)  loss_classifier: 0.0527 (0.0617)  loss_box_reg: 0.0519 (0.0537)  loss_objectness: 0.0029 (0.0067)  loss_rpn_box_reg: 0.0030 (0.0059)  time: 1.8386  data: 0.0071  max mem: 5436
# Epoch: [2]  [ 630/1142]  eta: 0:16:23  lr: 0.005000  loss: 0.1042 (0.1278)  loss_classifier: 0.0506 (0.0616)  loss_box_reg: 0.0505 (0.0536)  loss_objectness: 0.0051 (0.0067)  loss_rpn_box_reg: 0.0033 (0.0059)  time: 1.7510  data: 0.0071  max mem: 5436
# Epoch: [2]  [ 640/1142]  eta: 0:16:03  lr: 0.005000  loss: 0.1028 (0.1276)  loss_classifier: 0.0519 (0.0616)  loss_box_reg: 0.0419 (0.0534)  loss_objectness: 0.0051 (0.0068)  loss_rpn_box_reg: 0.0023 (0.0059)  time: 1.7540  data: 0.0070  max mem: 5436
# Epoch: [2]  [ 650/1142]  eta: 0:15:44  lr: 0.005000  loss: 0.1007 (0.1272)  loss_classifier: 0.0519 (0.0613)  loss_box_reg: 0.0419 (0.0533)  loss_objectness: 0.0038 (0.0068)  loss_rpn_box_reg: 0.0015 (0.0058)  time: 1.8960  data: 0.0072  max mem: 5436
# Epoch: [2]  [ 660/1142]  eta: 0:15:26  lr: 0.005000  loss: 0.0956 (0.1269)  loss_classifier: 0.0484 (0.0612)  loss_box_reg: 0.0426 (0.0531)  loss_objectness: 0.0035 (0.0068)  loss_rpn_box_reg: 0.0014 (0.0058)  time: 1.9997  data: 0.0072  max mem: 5436
# Epoch: [2]  [ 670/1142]  eta: 0:15:07  lr: 0.005000  loss: 0.0984 (0.1266)  loss_classifier: 0.0484 (0.0611)  loss_box_reg: 0.0432 (0.0530)  loss_objectness: 0.0028 (0.0067)  loss_rpn_box_reg: 0.0018 (0.0057)  time: 2.0492  data: 0.0070  max mem: 5436
# Epoch: [2]  [ 680/1142]  eta: 0:14:46  lr: 0.005000  loss: 0.1082 (0.1272)  loss_classifier: 0.0513 (0.0614)  loss_box_reg: 0.0515 (0.0534)  loss_objectness: 0.0044 (0.0067)  loss_rpn_box_reg: 0.0030 (0.0058)  time: 1.8000  data: 0.0071  max mem: 5436
# Epoch: [2]  [ 690/1142]  eta: 0:14:25  lr: 0.005000  loss: 0.1116 (0.1269)  loss_classifier: 0.0513 (0.0612)  loss_box_reg: 0.0466 (0.0533)  loss_objectness: 0.0042 (0.0067)  loss_rpn_box_reg: 0.0034 (0.0058)  time: 1.6489  data: 0.0070  max mem: 5436
# Epoch: [2]  [ 700/1142]  eta: 0:14:06  lr: 0.005000  loss: 0.1116 (0.1269)  loss_classifier: 0.0504 (0.0611)  loss_box_reg: 0.0457 (0.0533)  loss_objectness: 0.0029 (0.0067)  loss_rpn_box_reg: 0.0041 (0.0059)  time: 1.8493  data: 0.0070  max mem: 5436
# Epoch: [2]  [ 710/1142]  eta: 0:13:47  lr: 0.005000  loss: 0.1234 (0.1269)  loss_classifier: 0.0646 (0.0612)  loss_box_reg: 0.0457 (0.0532)  loss_objectness: 0.0037 (0.0067)  loss_rpn_box_reg: 0.0042 (0.0058)  time: 1.9371  data: 0.0071  max mem: 5436
# Epoch: [2]  [ 720/1142]  eta: 0:13:27  lr: 0.005000  loss: 0.1033 (0.1268)  loss_classifier: 0.0474 (0.0612)  loss_box_reg: 0.0430 (0.0532)  loss_objectness: 0.0022 (0.0066)  loss_rpn_box_reg: 0.0027 (0.0058)  time: 1.8050  data: 0.0068  max mem: 5436
# Epoch: [2]  [ 730/1142]  eta: 0:13:08  lr: 0.005000  loss: 0.1027 (0.1265)  loss_classifier: 0.0474 (0.0610)  loss_box_reg: 0.0430 (0.0531)  loss_objectness: 0.0032 (0.0066)  loss_rpn_box_reg: 0.0026 (0.0058)  time: 1.8139  data: 0.0068  max mem: 5436
# Epoch: [2]  [ 740/1142]  eta: 0:12:49  lr: 0.005000  loss: 0.1078 (0.1264)  loss_classifier: 0.0524 (0.0610)  loss_box_reg: 0.0464 (0.0530)  loss_objectness: 0.0038 (0.0066)  loss_rpn_box_reg: 0.0026 (0.0058)  time: 1.9056  data: 0.0065  max mem: 5436
# Epoch: [2]  [ 750/1142]  eta: 0:12:30  lr: 0.005000  loss: 0.1154 (0.1266)  loss_classifier: 0.0503 (0.0611)  loss_box_reg: 0.0551 (0.0531)  loss_objectness: 0.0025 (0.0066)  loss_rpn_box_reg: 0.0026 (0.0058)  time: 1.9327  data: 0.0065  max mem: 5436
# Epoch: [2]  [ 760/1142]  eta: 0:12:12  lr: 0.005000  loss: 0.1157 (0.1267)  loss_classifier: 0.0477 (0.0612)  loss_box_reg: 0.0464 (0.0531)  loss_objectness: 0.0020 (0.0066)  loss_rpn_box_reg: 0.0022 (0.0057)  time: 2.0933  data: 0.0070  max mem: 5436
# Epoch: [2]  [ 770/1142]  eta: 0:11:54  lr: 0.005000  loss: 0.1117 (0.1266)  loss_classifier: 0.0465 (0.0611)  loss_box_reg: 0.0464 (0.0531)  loss_objectness: 0.0020 (0.0066)  loss_rpn_box_reg: 0.0025 (0.0058)  time: 2.1716  data: 0.0069  max mem: 5436
# Epoch: [2]  [ 780/1142]  eta: 0:11:35  lr: 0.005000  loss: 0.0937 (0.1264)  loss_classifier: 0.0478 (0.0611)  loss_box_reg: 0.0474 (0.0530)  loss_objectness: 0.0021 (0.0066)  loss_rpn_box_reg: 0.0022 (0.0057)  time: 2.0122  data: 0.0070  max mem: 5436
# Epoch: [2]  [ 790/1142]  eta: 0:11:16  lr: 0.005000  loss: 0.1181 (0.1265)  loss_classifier: 0.0624 (0.0612)  loss_box_reg: 0.0431 (0.0529)  loss_objectness: 0.0035 (0.0066)  loss_rpn_box_reg: 0.0017 (0.0058)  time: 2.0064  data: 0.0074  max mem: 5436
# Epoch: [2]  [ 800/1142]  eta: 0:10:57  lr: 0.005000  loss: 0.1233 (0.1265)  loss_classifier: 0.0624 (0.0611)  loss_box_reg: 0.0450 (0.0529)  loss_objectness: 0.0066 (0.0067)  loss_rpn_box_reg: 0.0032 (0.0058)  time: 1.9660  data: 0.0072  max mem: 5436
# Epoch: [2]  [ 810/1142]  eta: 0:10:37  lr: 0.005000  loss: 0.1159 (0.1264)  loss_classifier: 0.0533 (0.0610)  loss_box_reg: 0.0489 (0.0529)  loss_objectness: 0.0036 (0.0067)  loss_rpn_box_reg: 0.0026 (0.0058)  time: 1.8308  data: 0.0070  max mem: 5436
# Epoch: [2]  [ 820/1142]  eta: 0:10:17  lr: 0.005000  loss: 0.1106 (0.1265)  loss_classifier: 0.0545 (0.0611)  loss_box_reg: 0.0463 (0.0529)  loss_objectness: 0.0041 (0.0067)  loss_rpn_box_reg: 0.0033 (0.0058)  time: 1.7650  data: 0.0072  max mem: 5436
# Epoch: [2]  [ 830/1142]  eta: 0:09:57  lr: 0.005000  loss: 0.1239 (0.1268)  loss_classifier: 0.0634 (0.0612)  loss_box_reg: 0.0501 (0.0531)  loss_objectness: 0.0061 (0.0066)  loss_rpn_box_reg: 0.0029 (0.0058)  time: 1.6453  data: 0.0070  max mem: 5436
# Epoch: [2]  [ 840/1142]  eta: 0:09:37  lr: 0.005000  loss: 0.1258 (0.1269)  loss_classifier: 0.0574 (0.0612)  loss_box_reg: 0.0588 (0.0532)  loss_objectness: 0.0060 (0.0067)  loss_rpn_box_reg: 0.0026 (0.0058)  time: 1.7263  data: 0.0069  max mem: 5436
# Epoch: [2]  [ 850/1142]  eta: 0:09:18  lr: 0.005000  loss: 0.1195 (0.1267)  loss_classifier: 0.0541 (0.0612)  loss_box_reg: 0.0426 (0.0531)  loss_objectness: 0.0060 (0.0067)  loss_rpn_box_reg: 0.0025 (0.0058)  time: 1.9165  data: 0.0073  max mem: 5436
# Epoch: [2]  [ 860/1142]  eta: 0:08:59  lr: 0.005000  loss: 0.1161 (0.1268)  loss_classifier: 0.0631 (0.0611)  loss_box_reg: 0.0476 (0.0532)  loss_objectness: 0.0040 (0.0066)  loss_rpn_box_reg: 0.0037 (0.0058)  time: 1.9663  data: 0.0072  max mem: 5436
# Epoch: [2]  [ 870/1142]  eta: 0:08:39  lr: 0.005000  loss: 0.1232 (0.1270)  loss_classifier: 0.0533 (0.0613)  loss_box_reg: 0.0599 (0.0533)  loss_objectness: 0.0022 (0.0066)  loss_rpn_box_reg: 0.0043 (0.0058)  time: 1.7874  data: 0.0070  max mem: 5436
# Epoch: [2]  [ 880/1142]  eta: 0:08:20  lr: 0.005000  loss: 0.1359 (0.1275)  loss_classifier: 0.0686 (0.0614)  loss_box_reg: 0.0619 (0.0535)  loss_objectness: 0.0034 (0.0067)  loss_rpn_box_reg: 0.0035 (0.0059)  time: 1.6866  data: 0.0070  max mem: 5436
# Epoch: [2]  [ 890/1142]  eta: 0:08:00  lr: 0.005000  loss: 0.1327 (0.1275)  loss_classifier: 0.0686 (0.0613)  loss_box_reg: 0.0539 (0.0534)  loss_objectness: 0.0061 (0.0067)  loss_rpn_box_reg: 0.0030 (0.0060)  time: 1.7286  data: 0.0069  max mem: 5436
# Epoch: [2]  [ 900/1142]  eta: 0:07:41  lr: 0.005000  loss: 0.0986 (0.1275)  loss_classifier: 0.0408 (0.0613)  loss_box_reg: 0.0422 (0.0534)  loss_objectness: 0.0042 (0.0067)  loss_rpn_box_reg: 0.0037 (0.0060)  time: 1.8956  data: 0.0083  max mem: 5436
# Epoch: [2]  [ 910/1142]  eta: 0:07:23  lr: 0.005000  loss: 0.1215 (0.1276)  loss_classifier: 0.0650 (0.0614)  loss_box_reg: 0.0519 (0.0535)  loss_objectness: 0.0029 (0.0067)  loss_rpn_box_reg: 0.0032 (0.0059)  time: 2.0455  data: 0.0105  max mem: 5436
# Epoch: [2]  [ 920/1142]  eta: 0:07:04  lr: 0.005000  loss: 0.1251 (0.1278)  loss_classifier: 0.0696 (0.0615)  loss_box_reg: 0.0533 (0.0536)  loss_objectness: 0.0029 (0.0067)  loss_rpn_box_reg: 0.0029 (0.0059)  time: 2.0148  data: 0.0100  max mem: 5436
# Epoch: [2]  [ 930/1142]  eta: 0:06:45  lr: 0.005000  loss: 0.1292 (0.1278)  loss_classifier: 0.0690 (0.0616)  loss_box_reg: 0.0533 (0.0536)  loss_objectness: 0.0029 (0.0067)  loss_rpn_box_reg: 0.0025 (0.0059)  time: 2.0364  data: 0.0089  max mem: 5436
# Epoch: [2]  [ 940/1142]  eta: 0:06:26  lr: 0.005000  loss: 0.1000 (0.1277)  loss_classifier: 0.0495 (0.0616)  loss_box_reg: 0.0448 (0.0535)  loss_objectness: 0.0028 (0.0067)  loss_rpn_box_reg: 0.0019 (0.0059)  time: 1.9474  data: 0.0094  max mem: 5436
# Epoch: [2]  [ 950/1142]  eta: 0:06:06  lr: 0.005000  loss: 0.1104 (0.1279)  loss_classifier: 0.0495 (0.0616)  loss_box_reg: 0.0509 (0.0537)  loss_objectness: 0.0042 (0.0067)  loss_rpn_box_reg: 0.0020 (0.0060)  time: 1.8598  data: 0.0088  max mem: 5436
# Epoch: [2]  [ 960/1142]  eta: 0:05:47  lr: 0.005000  loss: 0.1286 (0.1279)  loss_classifier: 0.0620 (0.0616)  loss_box_reg: 0.0558 (0.0536)  loss_objectness: 0.0043 (0.0067)  loss_rpn_box_reg: 0.0026 (0.0060)  time: 1.8089  data: 0.0087  max mem: 5436
# Epoch: [2]  [ 970/1142]  eta: 0:05:28  lr: 0.005000  loss: 0.1112 (0.1278)  loss_classifier: 0.0564 (0.0616)  loss_box_reg: 0.0445 (0.0535)  loss_objectness: 0.0036 (0.0067)  loss_rpn_box_reg: 0.0026 (0.0060)  time: 1.8877  data: 0.0103  max mem: 5436
# Epoch: [2]  [ 980/1142]  eta: 0:05:09  lr: 0.005000  loss: 0.1157 (0.1279)  loss_classifier: 0.0567 (0.0616)  loss_box_reg: 0.0450 (0.0536)  loss_objectness: 0.0053 (0.0067)  loss_rpn_box_reg: 0.0026 (0.0059)  time: 1.8721  data: 0.0102  max mem: 5436
# Epoch: [2]  [ 990/1142]  eta: 0:04:49  lr: 0.005000  loss: 0.1185 (0.1279)  loss_classifier: 0.0567 (0.0617)  loss_box_reg: 0.0502 (0.0535)  loss_objectness: 0.0059 (0.0067)  loss_rpn_box_reg: 0.0031 (0.0059)  time: 1.7029  data: 0.0087  max mem: 5436
# Epoch: [2]  [1000/1142]  eta: 0:04:30  lr: 0.005000  loss: 0.1280 (0.1283)  loss_classifier: 0.0649 (0.0619)  loss_box_reg: 0.0502 (0.0536)  loss_objectness: 0.0038 (0.0067)  loss_rpn_box_reg: 0.0052 (0.0060)  time: 1.8692  data: 0.0079  max mem: 5436
# Epoch: [2]  [1010/1142]  eta: 0:04:11  lr: 0.005000  loss: 0.1352 (0.1285)  loss_classifier: 0.0728 (0.0620)  loss_box_reg: 0.0546 (0.0537)  loss_objectness: 0.0070 (0.0068)  loss_rpn_box_reg: 0.0040 (0.0060)  time: 1.8574  data: 0.0090  max mem: 5436
# Epoch: [2]  [1020/1142]  eta: 0:03:52  lr: 0.005000  loss: 0.1115 (0.1285)  loss_classifier: 0.0561 (0.0621)  loss_box_reg: 0.0517 (0.0537)  loss_objectness: 0.0040 (0.0068)  loss_rpn_box_reg: 0.0023 (0.0059)  time: 1.7067  data: 0.0100  max mem: 5436
# Epoch: [2]  [1030/1142]  eta: 0:03:33  lr: 0.005000  loss: 0.1241 (0.1286)  loss_classifier: 0.0521 (0.0620)  loss_box_reg: 0.0511 (0.0538)  loss_objectness: 0.0038 (0.0068)  loss_rpn_box_reg: 0.0023 (0.0060)  time: 1.9294  data: 0.0077  max mem: 5436
# Epoch: [2]  [1040/1142]  eta: 0:03:14  lr: 0.005000  loss: 0.1271 (0.1286)  loss_classifier: 0.0521 (0.0620)  loss_box_reg: 0.0506 (0.0538)  loss_objectness: 0.0038 (0.0068)  loss_rpn_box_reg: 0.0031 (0.0061)  time: 2.1768  data: 0.0065  max mem: 5436
# Epoch: [2]  [1050/1142]  eta: 0:02:56  lr: 0.005000  loss: 0.1269 (0.1285)  loss_classifier: 0.0471 (0.0619)  loss_box_reg: 0.0462 (0.0537)  loss_objectness: 0.0020 (0.0068)  loss_rpn_box_reg: 0.0042 (0.0061)  time: 2.3915  data: 0.0072  max mem: 5436
# Epoch: [2]  [1060/1142]  eta: 0:02:37  lr: 0.005000  loss: 0.1269 (0.1286)  loss_classifier: 0.0546 (0.0620)  loss_box_reg: 0.0509 (0.0538)  loss_objectness: 0.0047 (0.0068)  loss_rpn_box_reg: 0.0040 (0.0061)  time: 2.6362  data: 0.0081  max mem: 5436
# Epoch: [2]  [1070/1142]  eta: 0:02:18  lr: 0.005000  loss: 0.1265 (0.1286)  loss_classifier: 0.0577 (0.0620)  loss_box_reg: 0.0535 (0.0538)  loss_objectness: 0.0038 (0.0068)  loss_rpn_box_reg: 0.0032 (0.0061)  time: 2.5892  data: 0.0075  max mem: 5436
# Epoch: [2]  [1080/1142]  eta: 0:01:59  lr: 0.005000  loss: 0.1265 (0.1286)  loss_classifier: 0.0444 (0.0619)  loss_box_reg: 0.0512 (0.0538)  loss_objectness: 0.0032 (0.0067)  loss_rpn_box_reg: 0.0033 (0.0061)  time: 2.4402  data: 0.0064  max mem: 5436
# Epoch: [2]  [1090/1142]  eta: 0:01:40  lr: 0.005000  loss: 0.1306 (0.1287)  loss_classifier: 0.0511 (0.0618)  loss_box_reg: 0.0539 (0.0539)  loss_objectness: 0.0022 (0.0067)  loss_rpn_box_reg: 0.0044 (0.0062)  time: 2.3327  data: 0.0071  max mem: 5436
# Epoch: [2]  [1100/1142]  eta: 0:01:21  lr: 0.005000  loss: 0.1422 (0.1291)  loss_classifier: 0.0705 (0.0621)  loss_box_reg: 0.0593 (0.0540)  loss_objectness: 0.0030 (0.0068)  loss_rpn_box_reg: 0.0029 (0.0062)  time: 2.2840  data: 0.0066  max mem: 5436
# Epoch: [2]  [1110/1142]  eta: 0:01:02  lr: 0.005000  loss: 0.1340 (0.1288)  loss_classifier: 0.0595 (0.0619)  loss_box_reg: 0.0440 (0.0539)  loss_objectness: 0.0061 (0.0068)  loss_rpn_box_reg: 0.0023 (0.0062)  time: 2.3963  data: 0.0075  max mem: 5436
# Epoch: [2]  [1120/1142]  eta: 0:00:42  lr: 0.005000  loss: 0.1121 (0.1289)  loss_classifier: 0.0555 (0.0621)  loss_box_reg: 0.0400 (0.0538)  loss_objectness: 0.0048 (0.0068)  loss_rpn_box_reg: 0.0026 (0.0062)  time: 2.2757  data: 0.0071  max mem: 5436
# Epoch: [2]  [1130/1142]  eta: 0:00:23  lr: 0.005000  loss: 0.1154 (0.1288)  loss_classifier: 0.0561 (0.0620)  loss_box_reg: 0.0444 (0.0538)  loss_objectness: 0.0068 (0.0068)  loss_rpn_box_reg: 0.0019 (0.0062)  time: 2.0897  data: 0.0056  max mem: 5436
# Epoch: [2]  [1140/1142]  eta: 0:00:03  lr: 0.005000  loss: 0.1128 (0.1288)  loss_classifier: 0.0521 (0.0620)  loss_box_reg: 0.0443 (0.0537)  loss_objectness: 0.0054 (0.0068)  loss_rpn_box_reg: 0.0027 (0.0062)  time: 2.0641  data: 0.0069  max mem: 5436
# Epoch: [2]  [1141/1142]  eta: 0:00:01  lr: 0.005000  loss: 0.1150 (0.1289)  loss_classifier: 0.0521 (0.0620)  loss_box_reg: 0.0441 (0.0537)  loss_objectness: 0.0054 (0.0068)  loss_rpn_box_reg: 0.0027 (0.0063)  time: 2.0742  data: 0.0073  max mem: 5436
# Epoch: [2] Total time: 0:37:03 (1.9471 s / it)
# Model saved to: D:/Projetos/pythonlib/working\model_20250105_144824.pth
# Training and plotting completed!
