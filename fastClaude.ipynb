# %%
import os
import torch
import pandas as pd
import ast
import torchvision
from torchvision.io import read_image
from torchvision import tv_tensors
from torchvision.transforms.v2 import functional as F
from torchvision.transforms import v2 as T
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.utils import draw_bounding_boxes
import utils
from engine import train_one_epoch, evaluate

def get_transform(train):
    transforms = []
    if train:
        transforms.append(T.RandomHorizontalFlip(0.5))
    transforms.append(T.ToDtype(torch.float, scale=True))
    transforms.append(T.ToPureTensor())
    return T.Compose(transforms)

class CocoSubsetDataset(torch.utils.data.Dataset):
    def __init__(self, csv_path, images_path, transforms=None):
        self.transforms = transforms
        self.images_path = images_path
        # Load CSV data
        self.df = pd.read_csv(csv_path)
        # Convert string representation of bbox to list
        self.df['bbox'] = self.df['bbox'].apply(ast.literal_eval)
        
        # Create category to id mapping
        self.category_to_id = {
            'person': 1,
            'cat': 2,
            'dog': 3
        }
        
    def __getitem__(self, idx):
        # Get all annotations for this image
        img_annots = self.df[self.df['image_id'] == self.df['image_id'].unique()[idx]]
        
        # Load image
        img_path = os.path.join(self.images_path, img_annots['image'].iloc[0])
        img = read_image(img_path)
        
        # If image is grayscale, convert to RGB
        if img.shape[0] == 1:
            img = img.repeat(3, 1, 1)
        
        # Get boxes and labels
        boxes = []
        labels = []
        
        for _, row in img_annots.iterrows():
            # Convert COCO bbox [x,y,width,height] to [x1,y1,x2,y2]
            bbox = row['bbox']
            boxes.append([
                bbox[0],
                bbox[1],
                bbox[0] + bbox[2],
                bbox[1] + bbox[3]
            ])
            labels.append(self.category_to_id[row['label']])
        
        # Convert to tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        
        # Prepare target dict
        img = tv_tensors.Image(img)
        target = {}
        target["boxes"] = tv_tensors.BoundingBoxes(boxes, format="XYXY", canvas_size=F.get_size(img))
        target["labels"] = labels
        target["image_id"] = torch.tensor([idx])
        
        if self.transforms is not None:
            img, target = self.transforms(img, target)
            
        return img, target
    
    def __len__(self):
        return len(self.df['image_id'].unique())

def get_model_detection(num_classes):
    # Load a pre-trained model
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights="DEFAULT")
    
    # Get number of input features
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    
    # Replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    
    return model

# Training setup
TRAIN_IMAGES_PATH = 'D:/Download/JDownloader/MSCOCO/images/train2017'
FILTERED_PATH = 'D:/Projetos/pythonlib/working'
CSV_PATH = os.path.join(FILTERED_PATH, 'filtered_coco.csv')

# Number of classes (background + person + cat + dog)
num_classes = 4

# Create train and test datasets
dataset = CocoSubsetDataset(CSV_PATH, TRAIN_IMAGES_PATH, get_transform(train=True))
dataset_test = CocoSubsetDataset(CSV_PATH, TRAIN_IMAGES_PATH, get_transform(train=False))

# Split dataset
indices = torch.randperm(len(dataset)).tolist()
train_size = int(0.8 * len(dataset))  # 80% for training
dataset = torch.utils.data.Subset(dataset, indices[:train_size])
dataset_test = torch.utils.data.Subset(dataset_test, indices[train_size:])

# Create data loaders
data_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
    collate_fn=utils.collate_fn
)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test,
    batch_size=1,
    shuffle=False,
    collate_fn=utils.collate_fn
)

# Initialize model, optimizer and scheduler
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model = get_model_detection(num_classes)
model.to(device)

# Optimize all parameters
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

# Training loop
num_epochs = 2

for epoch in range(num_epochs):
    # Train for one epoch
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
    
    # Update learning rate
    lr_scheduler.step()
    
    # Evaluate on test dataset
    evaluate(model, data_loader_test, device=device)

print("Training completed!")

# Visualization function
def visualize_predictions(model, image_path, device, transform):
    image = read_image(image_path)
    
    # Transform image
    image_transformed = transform(image)
    image_transformed = image_transformed[:3, ...].to(device)
    
    # Get predictions
    model.eval()
    with torch.no_grad():
        predictions = model([image_transformed])
        pred = predictions[0]
    
    # Convert image for visualization
    image = image[:3, ...]  # Remove alpha channel if present
    image = (255.0 * (image - image.min()) / (image.max() - image.min())).to(torch.uint8)
    
    # Draw bounding boxes
    pred_scores = pred["scores"] > 0.5
    pred_boxes = pred["boxes"][pred_scores].long()
    pred_labels = pred["labels"][pred_scores]
    
    # Convert numeric labels to text
    id_to_label = {1: 'person', 2: 'cat', 3: 'dog'}
    pred_label_texts = [f"{id_to_label[label.item()]}: {score:.2f}" 
                       for label, score in zip(pred_labels, pred["scores"][pred_scores])]
    
    # Draw boxes
    output_image = draw_bounding_boxes(
        image, 
        pred_boxes,
        pred_label_texts,
        colors="red"
    )
    
    return output_image
# Out:
# d:\Projetos\pythonlib\engine.py:30: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=scaler is not None):
# Epoch: [0]  [   0/1142]  eta: 0:13:34  lr: 0.000010  loss: 1.4338 (1.4338)  loss_classifier: 1.2881 (1.2881)  loss_box_reg: 0.1033 (0.1033)  loss_objectness: 0.0353 (0.0353)  loss_rpn_box_reg: 0.0071 (0.0071)  time: 0.7135  data: 0.0231  max mem: 4084
# Epoch: [0]  [  10/1142]  eta: 0:13:01  lr: 0.000060  loss: 1.3789 (1.3640)  loss_classifier: 1.1860 (1.1742)  loss_box_reg: 0.1185 (0.1174)  loss_objectness: 0.0362 (0.0666)  loss_rpn_box_reg: 0.0027 (0.0057)  time: 0.6900  data: 0.0218  max mem: 4310
# Epoch: [0]  [  20/1142]  eta: 0:12:57  lr: 0.000110  loss: 1.1136 (1.1394)  loss_classifier: 0.9500 (0.9517)  loss_box_reg: 0.1204 (0.1313)  loss_objectness: 0.0204 (0.0510)  loss_rpn_box_reg: 0.0032 (0.0054)  time: 0.6924  data: 0.0215  max mem: 4317
# Epoch: [0]  [  30/1142]  eta: 0:13:48  lr: 0.000160  loss: 0.5825 (0.9294)  loss_classifier: 0.3837 (0.7369)  loss_box_reg: 0.1451 (0.1476)  loss_objectness: 0.0090 (0.0399)  loss_rpn_box_reg: 0.0039 (0.0050)  time: 0.7758  data: 0.0190  max mem: 4569
# Epoch: [0]  [  40/1142]  eta: 0:13:29  lr: 0.000210  loss: 0.3535 (0.7872)  loss_classifier: 0.1946 (0.5997)  loss_box_reg: 0.1318 (0.1448)  loss_objectness: 0.0095 (0.0376)  loss_rpn_box_reg: 0.0025 (0.0051)  time: 0.7784  data: 0.0164  max mem: 4571
# Epoch: [0]  [  50/1142]  eta: 0:13:14  lr: 0.000260  loss: 0.3319 (0.6959)  loss_classifier: 0.1680 (0.5145)  loss_box_reg: 0.1318 (0.1429)  loss_objectness: 0.0080 (0.0335)  loss_rpn_box_reg: 0.0021 (0.0049)  time: 0.6996  data: 0.0162  max mem: 4571
# Epoch: [0]  [  60/1142]  eta: 0:12:52  lr: 0.000310  loss: 0.2887 (0.6297)  loss_classifier: 0.1407 (0.4527)  loss_box_reg: 0.1226 (0.1370)  loss_objectness: 0.0141 (0.0345)  loss_rpn_box_reg: 0.0018 (0.0055)  time: 0.6703  data: 0.0165  max mem: 4571
# Epoch: [0]  [  70/1142]  eta: 0:12:49  lr: 0.000360  loss: 0.2751 (0.5855)  loss_classifier: 0.1355 (0.4105)  loss_box_reg: 0.1138 (0.1369)  loss_objectness: 0.0162 (0.0327)  loss_rpn_box_reg: 0.0015 (0.0054)  time: 0.6943  data: 0.0176  max mem: 4571
# Epoch: [0]  [  80/1142]  eta: 0:12:53  lr: 0.000410  loss: 0.2920 (0.5548)  loss_classifier: 0.1428 (0.3786)  loss_box_reg: 0.1435 (0.1396)  loss_objectness: 0.0152 (0.0313)  loss_rpn_box_reg: 0.0019 (0.0053)  time: 0.7739  data: 0.0182  max mem: 4571
# Epoch: [0]  [  90/1142]  eta: 0:12:44  lr: 0.000460  loss: 0.2953 (0.5244)  loss_classifier: 0.1373 (0.3506)  loss_box_reg: 0.1455 (0.1380)  loss_objectness: 0.0052 (0.0303)  loss_rpn_box_reg: 0.0036 (0.0055)  time: 0.7594  data: 0.0175  max mem: 4571
# Epoch: [0]  [ 100/1142]  eta: 0:12:39  lr: 0.000509  loss: 0.2538 (0.4970)  loss_classifier: 0.1093 (0.3266)  loss_box_reg: 0.1106 (0.1353)  loss_objectness: 0.0111 (0.0293)  loss_rpn_box_reg: 0.0049 (0.0057)  time: 0.7320  data: 0.0175  max mem: 4571
# Epoch: [0]  [ 110/1142]  eta: 0:12:21  lr: 0.000559  loss: 0.2448 (0.4741)  loss_classifier: 0.1104 (0.3068)  loss_box_reg: 0.1052 (0.1333)  loss_objectness: 0.0159 (0.0283)  loss_rpn_box_reg: 0.0034 (0.0056)  time: 0.6783  data: 0.0171  max mem: 4571
# Epoch: [0]  [ 120/1142]  eta: 0:12:11  lr: 0.000609  loss: 0.2397 (0.4549)  loss_classifier: 0.1064 (0.2904)  loss_box_reg: 0.1052 (0.1319)  loss_objectness: 0.0120 (0.0270)  loss_rpn_box_reg: 0.0025 (0.0055)  time: 0.6490  data: 0.0167  max mem: 4571
# Epoch: [0]  [ 130/1142]  eta: 0:11:55  lr: 0.000659  loss: 0.2390 (0.4387)  loss_classifier: 0.0921 (0.2758)  loss_box_reg: 0.1216 (0.1315)  loss_objectness: 0.0074 (0.0262)  loss_rpn_box_reg: 0.0014 (0.0052)  time: 0.6468  data: 0.0176  max mem: 4571
# Epoch: [0]  [ 140/1142]  eta: 0:11:43  lr: 0.000709  loss: 0.2505 (0.4274)  loss_classifier: 0.0921 (0.2642)  loss_box_reg: 0.1292 (0.1332)  loss_objectness: 0.0042 (0.0249)  loss_rpn_box_reg: 0.0016 (0.0051)  time: 0.6210  data: 0.0168  max mem: 4571
# Epoch: [0]  [ 150/1142]  eta: 0:11:42  lr: 0.000759  loss: 0.2505 (0.4170)  loss_classifier: 0.1002 (0.2530)  loss_box_reg: 0.1328 (0.1349)  loss_objectness: 0.0046 (0.0240)  loss_rpn_box_reg: 0.0024 (0.0051)  time: 0.7105  data: 0.0163  max mem: 4735
# Epoch: [0]  [ 160/1142]  eta: 0:11:41  lr: 0.000809  loss: 0.2251 (0.4035)  loss_classifier: 0.0798 (0.2417)  loss_box_reg: 0.1201 (0.1336)  loss_objectness: 0.0057 (0.0229)  loss_rpn_box_reg: 0.0038 (0.0052)  time: 0.7941  data: 0.0166  max mem: 4904
# Epoch: [0]  [ 170/1142]  eta: 0:11:31  lr: 0.000859  loss: 0.1819 (0.3925)  loss_classifier: 0.0667 (0.2328)  loss_box_reg: 0.0979 (0.1321)  loss_objectness: 0.0050 (0.0222)  loss_rpn_box_reg: 0.0034 (0.0053)  time: 0.7390  data: 0.0157  max mem: 4904
# Epoch: [0]  [ 180/1142]  eta: 0:11:22  lr: 0.000909  loss: 0.2096 (0.3832)  loss_classifier: 0.0874 (0.2250)  loss_box_reg: 0.1047 (0.1314)  loss_objectness: 0.0068 (0.0216)  loss_rpn_box_reg: 0.0019 (0.0053)  time: 0.6762  data: 0.0149  max mem: 4904
# Epoch: [0]  [ 190/1142]  eta: 0:11:16  lr: 0.000959  loss: 0.2086 (0.3730)  loss_classifier: 0.0856 (0.2172)  loss_box_reg: 0.1138 (0.1299)  loss_objectness: 0.0048 (0.0208)  loss_rpn_box_reg: 0.0030 (0.0052)  time: 0.7061  data: 0.0149  max mem: 4904
# Epoch: [0]  [ 200/1142]  eta: 0:11:07  lr: 0.001009  loss: 0.1887 (0.3648)  loss_classifier: 0.0781 (0.2103)  loss_box_reg: 0.1022 (0.1287)  loss_objectness: 0.0056 (0.0205)  loss_rpn_box_reg: 0.0036 (0.0053)  time: 0.7023  data: 0.0185  max mem: 4904
# Epoch: [0]  [ 210/1142]  eta: 0:11:07  lr: 0.001059  loss: 0.2052 (0.3589)  loss_classifier: 0.0744 (0.2042)  loss_box_reg: 0.1051 (0.1278)  loss_objectness: 0.0097 (0.0215)  loss_rpn_box_reg: 0.0036 (0.0053)  time: 0.7624  data: 0.0205  max mem: 4904
# Epoch: [0]  [ 220/1142]  eta: 0:10:58  lr: 0.001109  loss: 0.2052 (0.3514)  loss_classifier: 0.0762 (0.1984)  loss_box_reg: 0.1051 (0.1267)  loss_objectness: 0.0047 (0.0210)  loss_rpn_box_reg: 0.0020 (0.0052)  time: 0.7724  data: 0.0179  max mem: 4904
# Epoch: [0]  [ 230/1142]  eta: 0:10:54  lr: 0.001159  loss: 0.1832 (0.3443)  loss_classifier: 0.0707 (0.1929)  loss_box_reg: 0.1000 (0.1254)  loss_objectness: 0.0047 (0.0207)  loss_rpn_box_reg: 0.0028 (0.0053)  time: 0.7379  data: 0.0159  max mem: 4904
# Epoch: [0]  [ 240/1142]  eta: 0:10:46  lr: 0.001209  loss: 0.1925 (0.3382)  loss_classifier: 0.0722 (0.1882)  loss_box_reg: 0.0969 (0.1246)  loss_objectness: 0.0062 (0.0202)  loss_rpn_box_reg: 0.0016 (0.0052)  time: 0.7343  data: 0.0171  max mem: 4904
# Epoch: [0]  [ 250/1142]  eta: 0:10:37  lr: 0.001259  loss: 0.1925 (0.3325)  loss_classifier: 0.0774 (0.1839)  loss_box_reg: 0.0969 (0.1236)  loss_objectness: 0.0062 (0.0199)  loss_rpn_box_reg: 0.0017 (0.0051)  time: 0.6821  data: 0.0186  max mem: 4904
# Epoch: [0]  [ 260/1142]  eta: 0:10:29  lr: 0.001309  loss: 0.1594 (0.3258)  loss_classifier: 0.0537 (0.1789)  loss_box_reg: 0.0897 (0.1219)  loss_objectness: 0.0094 (0.0199)  loss_rpn_box_reg: 0.0017 (0.0051)  time: 0.6760  data: 0.0192  max mem: 4904
# Epoch: [0]  [ 270/1142]  eta: 0:10:19  lr: 0.001359  loss: 0.1768 (0.3213)  loss_classifier: 0.0703 (0.1752)  loss_box_reg: 0.0899 (0.1211)  loss_objectness: 0.0094 (0.0199)  loss_rpn_box_reg: 0.0018 (0.0051)  time: 0.6576  data: 0.0205  max mem: 4904
# Epoch: [0]  [ 280/1142]  eta: 0:10:10  lr: 0.001409  loss: 0.1725 (0.3157)  loss_classifier: 0.0695 (0.1712)  loss_box_reg: 0.0899 (0.1197)  loss_objectness: 0.0080 (0.0197)  loss_rpn_box_reg: 0.0028 (0.0051)  time: 0.6415  data: 0.0207  max mem: 4904
# Epoch: [0]  [ 290/1142]  eta: 0:10:07  lr: 0.001459  loss: 0.1725 (0.3109)  loss_classifier: 0.0634 (0.1678)  loss_box_reg: 0.0766 (0.1184)  loss_objectness: 0.0070 (0.0193)  loss_rpn_box_reg: 0.0031 (0.0054)  time: 0.7524  data: 0.0204  max mem: 4904
# Epoch: [0]  [ 300/1142]  eta: 0:10:00  lr: 0.001508  loss: 0.1931 (0.3072)  loss_classifier: 0.0829 (0.1650)  loss_box_reg: 0.0886 (0.1177)  loss_objectness: 0.0061 (0.0190)  loss_rpn_box_reg: 0.0030 (0.0056)  time: 0.7818  data: 0.0203  max mem: 4904
# Epoch: [0]  [ 310/1142]  eta: 0:09:58  lr: 0.001558  loss: 0.1713 (0.3027)  loss_classifier: 0.0749 (0.1621)  loss_box_reg: 0.0938 (0.1165)  loss_objectness: 0.0033 (0.0186)  loss_rpn_box_reg: 0.0028 (0.0055)  time: 0.8136  data: 0.0187  max mem: 4904
# Epoch: [0]  [ 320/1142]  eta: 0:09:49  lr: 0.001608  loss: 0.1434 (0.2983)  loss_classifier: 0.0585 (0.1587)  loss_box_reg: 0.0787 (0.1155)  loss_objectness: 0.0069 (0.0184)  loss_rpn_box_reg: 0.0042 (0.0057)  time: 0.7748  data: 0.0175  max mem: 4904
# Epoch: [0]  [ 330/1142]  eta: 0:09:39  lr: 0.001658  loss: 0.1466 (0.2953)  loss_classifier: 0.0564 (0.1563)  loss_box_reg: 0.0836 (0.1150)  loss_objectness: 0.0095 (0.0182)  loss_rpn_box_reg: 0.0021 (0.0058)  time: 0.6162  data: 0.0183  max mem: 4904
# Epoch: [0]  [ 340/1142]  eta: 0:09:37  lr: 0.001708  loss: 0.1789 (0.2916)  loss_classifier: 0.0600 (0.1539)  loss_box_reg: 0.0865 (0.1142)  loss_objectness: 0.0051 (0.0178)  loss_rpn_box_reg: 0.0018 (0.0057)  time: 0.7796  data: 0.0201  max mem: 4904
# Epoch: [0]  [ 350/1142]  eta: 0:09:31  lr: 0.001758  loss: 0.1712 (0.2880)  loss_classifier: 0.0641 (0.1514)  loss_box_reg: 0.0795 (0.1131)  loss_objectness: 0.0039 (0.0177)  loss_rpn_box_reg: 0.0026 (0.0058)  time: 0.8544  data: 0.0203  max mem: 4904
# Epoch: [0]  [ 360/1142]  eta: 0:09:25  lr: 0.001808  loss: 0.1659 (0.2848)  loss_classifier: 0.0703 (0.1490)  loss_box_reg: 0.0776 (0.1124)  loss_objectness: 0.0061 (0.0175)  loss_rpn_box_reg: 0.0027 (0.0059)  time: 0.7576  data: 0.0175  max mem: 4904
# Epoch: [0]  [ 370/1142]  eta: 0:09:20  lr: 0.001858  loss: 0.1510 (0.2815)  loss_classifier: 0.0623 (0.1468)  loss_box_reg: 0.0823 (0.1116)  loss_objectness: 0.0055 (0.0171)  loss_rpn_box_reg: 0.0027 (0.0060)  time: 0.8036  data: 0.0173  max mem: 4904
# Epoch: [0]  [ 380/1142]  eta: 0:09:12  lr: 0.001908  loss: 0.1458 (0.2786)  loss_classifier: 0.0632 (0.1449)  loss_box_reg: 0.0743 (0.1106)  loss_objectness: 0.0036 (0.0172)  loss_rpn_box_reg: 0.0028 (0.0059)  time: 0.7643  data: 0.0190  max mem: 4904
# Epoch: [0]  [ 390/1142]  eta: 0:09:04  lr: 0.001958  loss: 0.1708 (0.2756)  loss_classifier: 0.0701 (0.1431)  loss_box_reg: 0.0743 (0.1096)  loss_objectness: 0.0076 (0.0171)  loss_rpn_box_reg: 0.0031 (0.0059)  time: 0.6838  data: 0.0200  max mem: 4904
# Epoch: [0]  [ 400/1142]  eta: 0:08:58  lr: 0.002008  loss: 0.1709 (0.2730)  loss_classifier: 0.0690 (0.1414)  loss_box_reg: 0.0851 (0.1090)  loss_objectness: 0.0087 (0.0168)  loss_rpn_box_reg: 0.0019 (0.0058)  time: 0.7342  data: 0.0203  max mem: 4904
# Epoch: [0]  [ 410/1142]  eta: 0:08:51  lr: 0.002058  loss: 0.1603 (0.2708)  loss_classifier: 0.0579 (0.1398)  loss_box_reg: 0.0852 (0.1086)  loss_objectness: 0.0028 (0.0166)  loss_rpn_box_reg: 0.0019 (0.0058)  time: 0.7768  data: 0.0185  max mem: 4904
# Epoch: [0]  [ 420/1142]  eta: 0:08:44  lr: 0.002108  loss: 0.1603 (0.2688)  loss_classifier: 0.0701 (0.1385)  loss_box_reg: 0.0852 (0.1083)  loss_objectness: 0.0028 (0.0163)  loss_rpn_box_reg: 0.0026 (0.0057)  time: 0.7466  data: 0.0180  max mem: 4904
# Epoch: [0]  [ 430/1142]  eta: 0:08:37  lr: 0.002158  loss: 0.1603 (0.2663)  loss_classifier: 0.0671 (0.1369)  loss_box_reg: 0.0753 (0.1075)  loss_objectness: 0.0060 (0.0161)  loss_rpn_box_reg: 0.0028 (0.0058)  time: 0.7311  data: 0.0178  max mem: 4904
# Epoch: [0]  [ 440/1142]  eta: 0:08:30  lr: 0.002208  loss: 0.1558 (0.2639)  loss_classifier: 0.0597 (0.1353)  loss_box_reg: 0.0716 (0.1070)  loss_objectness: 0.0050 (0.0159)  loss_rpn_box_reg: 0.0029 (0.0058)  time: 0.7557  data: 0.0189  max mem: 4904
# Epoch: [0]  [ 450/1142]  eta: 0:08:23  lr: 0.002258  loss: 0.1475 (0.2615)  loss_classifier: 0.0597 (0.1338)  loss_box_reg: 0.0709 (0.1062)  loss_objectness: 0.0029 (0.0156)  loss_rpn_box_reg: 0.0030 (0.0058)  time: 0.7307  data: 0.0191  max mem: 4904
# Epoch: [0]  [ 460/1142]  eta: 0:08:16  lr: 0.002308  loss: 0.1555 (0.2600)  loss_classifier: 0.0736 (0.1328)  loss_box_reg: 0.0692 (0.1057)  loss_objectness: 0.0069 (0.0158)  loss_rpn_box_reg: 0.0037 (0.0058)  time: 0.7450  data: 0.0179  max mem: 4904
# Epoch: [0]  [ 470/1142]  eta: 0:08:08  lr: 0.002358  loss: 0.1830 (0.2582)  loss_classifier: 0.0775 (0.1316)  loss_box_reg: 0.0751 (0.1052)  loss_objectness: 0.0072 (0.0157)  loss_rpn_box_reg: 0.0024 (0.0058)  time: 0.7234  data: 0.0188  max mem: 4904
# Epoch: [0]  [ 480/1142]  eta: 0:08:00  lr: 0.002408  loss: 0.1720 (0.2563)  loss_classifier: 0.0629 (0.1300)  loss_box_reg: 0.0798 (0.1045)  loss_objectness: 0.0069 (0.0158)  loss_rpn_box_reg: 0.0020 (0.0059)  time: 0.6768  data: 0.0195  max mem: 4904
# Epoch: [0]  [ 490/1142]  eta: 0:07:52  lr: 0.002458  loss: 0.1704 (0.2547)  loss_classifier: 0.0615 (0.1292)  loss_box_reg: 0.0628 (0.1040)  loss_objectness: 0.0069 (0.0157)  loss_rpn_box_reg: 0.0021 (0.0058)  time: 0.6819  data: 0.0193  max mem: 4904
# Epoch: [0]  [ 500/1142]  eta: 0:07:44  lr: 0.002507  loss: 0.1461 (0.2523)  loss_classifier: 0.0767 (0.1280)  loss_box_reg: 0.0574 (0.1030)  loss_objectness: 0.0041 (0.0155)  loss_rpn_box_reg: 0.0019 (0.0058)  time: 0.6573  data: 0.0182  max mem: 4904
# Epoch: [0]  [ 510/1142]  eta: 0:07:38  lr: 0.002557  loss: 0.1373 (0.2504)  loss_classifier: 0.0644 (0.1268)  loss_box_reg: 0.0557 (0.1023)  loss_objectness: 0.0029 (0.0154)  loss_rpn_box_reg: 0.0019 (0.0058)  time: 0.7339  data: 0.0187  max mem: 4904
# Epoch: [0]  [ 520/1142]  eta: 0:07:30  lr: 0.002607  loss: 0.1525 (0.2487)  loss_classifier: 0.0708 (0.1261)  loss_box_reg: 0.0574 (0.1016)  loss_objectness: 0.0055 (0.0153)  loss_rpn_box_reg: 0.0020 (0.0057)  time: 0.7471  data: 0.0203  max mem: 4904
# Epoch: [0]  [ 530/1142]  eta: 0:07:22  lr: 0.002657  loss: 0.1388 (0.2472)  loss_classifier: 0.0752 (0.1254)  loss_box_reg: 0.0591 (0.1011)  loss_objectness: 0.0038 (0.0151)  loss_rpn_box_reg: 0.0015 (0.0057)  time: 0.6596  data: 0.0203  max mem: 4904
# Epoch: [0]  [ 540/1142]  eta: 0:07:14  lr: 0.002707  loss: 0.1576 (0.2457)  loss_classifier: 0.0748 (0.1245)  loss_box_reg: 0.0703 (0.1007)  loss_objectness: 0.0014 (0.0149)  loss_rpn_box_reg: 0.0013 (0.0056)  time: 0.6525  data: 0.0200  max mem: 4904
# Epoch: [0]  [ 550/1142]  eta: 0:07:07  lr: 0.002757  loss: 0.1642 (0.2449)  loss_classifier: 0.0770 (0.1238)  loss_box_reg: 0.0811 (0.1006)  loss_objectness: 0.0028 (0.0147)  loss_rpn_box_reg: 0.0015 (0.0057)  time: 0.7137  data: 0.0187  max mem: 4904
# Epoch: [0]  [ 560/1142]  eta: 0:06:59  lr: 0.002807  loss: 0.1584 (0.2431)  loss_classifier: 0.0729 (0.1229)  loss_box_reg: 0.0788 (0.1000)  loss_objectness: 0.0037 (0.0145)  loss_rpn_box_reg: 0.0026 (0.0057)  time: 0.7181  data: 0.0171  max mem: 4904
# Epoch: [0]  [ 570/1142]  eta: 0:06:52  lr: 0.002857  loss: 0.1532 (0.2422)  loss_classifier: 0.0778 (0.1223)  loss_box_reg: 0.0714 (0.0997)  loss_objectness: 0.0040 (0.0145)  loss_rpn_box_reg: 0.0022 (0.0057)  time: 0.6643  data: 0.0183  max mem: 4904
# Epoch: [0]  [ 580/1142]  eta: 0:06:45  lr: 0.002907  loss: 0.1532 (0.2404)  loss_classifier: 0.0698 (0.1212)  loss_box_reg: 0.0687 (0.0993)  loss_objectness: 0.0040 (0.0143)  loss_rpn_box_reg: 0.0017 (0.0056)  time: 0.7036  data: 0.0189  max mem: 4904
# Epoch: [0]  [ 590/1142]  eta: 0:06:38  lr: 0.002957  loss: 0.1205 (0.2386)  loss_classifier: 0.0538 (0.1201)  loss_box_reg: 0.0581 (0.0985)  loss_objectness: 0.0012 (0.0142)  loss_rpn_box_reg: 0.0023 (0.0058)  time: 0.7849  data: 0.0179  max mem: 4904
# Epoch: [0]  [ 600/1142]  eta: 0:06:31  lr: 0.003007  loss: 0.1288 (0.2368)  loss_classifier: 0.0558 (0.1191)  loss_box_reg: 0.0547 (0.0979)  loss_objectness: 0.0014 (0.0140)  loss_rpn_box_reg: 0.0048 (0.0058)  time: 0.7429  data: 0.0171  max mem: 4904
# Epoch: [0]  [ 610/1142]  eta: 0:06:24  lr: 0.003057  loss: 0.1296 (0.2354)  loss_classifier: 0.0537 (0.1182)  loss_box_reg: 0.0563 (0.0971)  loss_objectness: 0.0031 (0.0142)  loss_rpn_box_reg: 0.0023 (0.0059)  time: 0.7422  data: 0.0181  max mem: 4904
# Epoch: [0]  [ 620/1142]  eta: 0:06:17  lr: 0.003107  loss: 0.1498 (0.2343)  loss_classifier: 0.0544 (0.1175)  loss_box_reg: 0.0610 (0.0968)  loss_objectness: 0.0057 (0.0141)  loss_rpn_box_reg: 0.0024 (0.0059)  time: 0.7870  data: 0.0194  max mem: 4904
# Epoch: [0]  [ 630/1142]  eta: 0:06:10  lr: 0.003157  loss: 0.1395 (0.2326)  loss_classifier: 0.0645 (0.1165)  loss_box_reg: 0.0627 (0.0962)  loss_objectness: 0.0068 (0.0140)  loss_rpn_box_reg: 0.0027 (0.0058)  time: 0.7642  data: 0.0199  max mem: 4904
# Epoch: [0]  [ 640/1142]  eta: 0:06:03  lr: 0.003207  loss: 0.1210 (0.2314)  loss_classifier: 0.0624 (0.1159)  loss_box_reg: 0.0579 (0.0956)  loss_objectness: 0.0092 (0.0140)  loss_rpn_box_reg: 0.0025 (0.0058)  time: 0.7158  data: 0.0188  max mem: 4904
# Epoch: [0]  [ 650/1142]  eta: 0:05:55  lr: 0.003257  loss: 0.1321 (0.2299)  loss_classifier: 0.0591 (0.1150)  loss_box_reg: 0.0584 (0.0951)  loss_objectness: 0.0095 (0.0139)  loss_rpn_box_reg: 0.0031 (0.0059)  time: 0.6803  data: 0.0170  max mem: 4904
# Epoch: [0]  [ 660/1142]  eta: 0:05:49  lr: 0.003307  loss: 0.1237 (0.2282)  loss_classifier: 0.0540 (0.1141)  loss_box_reg: 0.0528 (0.0944)  loss_objectness: 0.0059 (0.0138)  loss_rpn_box_reg: 0.0020 (0.0059)  time: 0.7419  data: 0.0193  max mem: 4904
# Epoch: [0]  [ 670/1142]  eta: 0:05:41  lr: 0.003357  loss: 0.1237 (0.2269)  loss_classifier: 0.0579 (0.1134)  loss_box_reg: 0.0571 (0.0939)  loss_objectness: 0.0032 (0.0137)  loss_rpn_box_reg: 0.0025 (0.0059)  time: 0.7455  data: 0.0218  max mem: 4904
# Epoch: [0]  [ 680/1142]  eta: 0:05:34  lr: 0.003407  loss: 0.1461 (0.2258)  loss_classifier: 0.0663 (0.1128)  loss_box_reg: 0.0602 (0.0933)  loss_objectness: 0.0043 (0.0137)  loss_rpn_box_reg: 0.0035 (0.0060)  time: 0.7109  data: 0.0209  max mem: 4904
# Epoch: [0]  [ 690/1142]  eta: 0:05:28  lr: 0.003457  loss: 0.1412 (0.2249)  loss_classifier: 0.0707 (0.1124)  loss_box_reg: 0.0557 (0.0929)  loss_objectness: 0.0058 (0.0136)  loss_rpn_box_reg: 0.0038 (0.0060)  time: 0.8038  data: 0.0199  max mem: 4904
# Epoch: [0]  [ 700/1142]  eta: 0:05:21  lr: 0.003506  loss: 0.1323 (0.2239)  loss_classifier: 0.0708 (0.1118)  loss_box_reg: 0.0583 (0.0926)  loss_objectness: 0.0056 (0.0135)  loss_rpn_box_reg: 0.0028 (0.0059)  time: 0.8337  data: 0.0175  max mem: 4904
# Epoch: [0]  [ 710/1142]  eta: 0:05:13  lr: 0.003556  loss: 0.1243 (0.2227)  loss_classifier: 0.0478 (0.1111)  loss_box_reg: 0.0601 (0.0921)  loss_objectness: 0.0040 (0.0134)  loss_rpn_box_reg: 0.0024 (0.0060)  time: 0.7350  data: 0.0145  max mem: 4904
# Epoch: [0]  [ 720/1142]  eta: 0:05:06  lr: 0.003606  loss: 0.1283 (0.2217)  loss_classifier: 0.0673 (0.1105)  loss_box_reg: 0.0524 (0.0917)  loss_objectness: 0.0044 (0.0135)  loss_rpn_box_reg: 0.0027 (0.0060)  time: 0.7084  data: 0.0151  max mem: 4904
# Epoch: [0]  [ 730/1142]  eta: 0:04:59  lr: 0.003656  loss: 0.1469 (0.2208)  loss_classifier: 0.0673 (0.1099)  loss_box_reg: 0.0525 (0.0914)  loss_objectness: 0.0063 (0.0135)  loss_rpn_box_reg: 0.0027 (0.0060)  time: 0.7580  data: 0.0171  max mem: 4904
# Epoch: [0]  [ 740/1142]  eta: 0:04:52  lr: 0.003706  loss: 0.1332 (0.2194)  loss_classifier: 0.0541 (0.1091)  loss_box_reg: 0.0617 (0.0909)  loss_objectness: 0.0056 (0.0134)  loss_rpn_box_reg: 0.0030 (0.0060)  time: 0.7463  data: 0.0177  max mem: 4904
# Epoch: [0]  [ 750/1142]  eta: 0:04:44  lr: 0.003756  loss: 0.1261 (0.2182)  loss_classifier: 0.0523 (0.1086)  loss_box_reg: 0.0538 (0.0904)  loss_objectness: 0.0037 (0.0133)  loss_rpn_box_reg: 0.0020 (0.0059)  time: 0.6733  data: 0.0174  max mem: 4904
# Epoch: [0]  [ 760/1142]  eta: 0:04:37  lr: 0.003806  loss: 0.1235 (0.2173)  loss_classifier: 0.0618 (0.1081)  loss_box_reg: 0.0592 (0.0902)  loss_objectness: 0.0016 (0.0131)  loss_rpn_box_reg: 0.0020 (0.0059)  time: 0.7372  data: 0.0180  max mem: 4904
# Epoch: [0]  [ 770/1142]  eta: 0:04:30  lr: 0.003856  loss: 0.1477 (0.2170)  loss_classifier: 0.0719 (0.1079)  loss_box_reg: 0.0598 (0.0899)  loss_objectness: 0.0057 (0.0132)  loss_rpn_box_reg: 0.0023 (0.0060)  time: 0.7638  data: 0.0180  max mem: 4904
# Epoch: [0]  [ 780/1142]  eta: 0:04:22  lr: 0.003906  loss: 0.1603 (0.2160)  loss_classifier: 0.0721 (0.1073)  loss_box_reg: 0.0592 (0.0895)  loss_objectness: 0.0095 (0.0132)  loss_rpn_box_reg: 0.0046 (0.0060)  time: 0.6562  data: 0.0158  max mem: 4904
# Epoch: [0]  [ 790/1142]  eta: 0:04:15  lr: 0.003956  loss: 0.1367 (0.2151)  loss_classifier: 0.0555 (0.1067)  loss_box_reg: 0.0599 (0.0893)  loss_objectness: 0.0066 (0.0131)  loss_rpn_box_reg: 0.0046 (0.0060)  time: 0.6974  data: 0.0159  max mem: 4904
# Epoch: [0]  [ 800/1142]  eta: 0:04:08  lr: 0.004006  loss: 0.1515 (0.2147)  loss_classifier: 0.0584 (0.1064)  loss_box_reg: 0.0624 (0.0892)  loss_objectness: 0.0084 (0.0131)  loss_rpn_box_reg: 0.0029 (0.0060)  time: 0.7487  data: 0.0176  max mem: 4904
# Epoch: [0]  [ 810/1142]  eta: 0:04:01  lr: 0.004056  loss: 0.1288 (0.2138)  loss_classifier: 0.0572 (0.1059)  loss_box_reg: 0.0615 (0.0888)  loss_objectness: 0.0095 (0.0131)  loss_rpn_box_reg: 0.0035 (0.0061)  time: 0.7239  data: 0.0178  max mem: 4904
# Epoch: [0]  [ 820/1142]  eta: 0:03:53  lr: 0.004106  loss: 0.1280 (0.2129)  loss_classifier: 0.0535 (0.1054)  loss_box_reg: 0.0619 (0.0885)  loss_objectness: 0.0038 (0.0130)  loss_rpn_box_reg: 0.0030 (0.0060)  time: 0.6788  data: 0.0169  max mem: 4904
# Epoch: [0]  [ 830/1142]  eta: 0:03:46  lr: 0.004156  loss: 0.1318 (0.2121)  loss_classifier: 0.0722 (0.1050)  loss_box_reg: 0.0626 (0.0882)  loss_objectness: 0.0032 (0.0129)  loss_rpn_box_reg: 0.0029 (0.0060)  time: 0.7062  data: 0.0162  max mem: 4904
# Epoch: [0]  [ 840/1142]  eta: 0:03:38  lr: 0.004206  loss: 0.1301 (0.2115)  loss_classifier: 0.0694 (0.1046)  loss_box_reg: 0.0562 (0.0879)  loss_objectness: 0.0043 (0.0129)  loss_rpn_box_reg: 0.0036 (0.0061)  time: 0.7218  data: 0.0172  max mem: 4904
# Epoch: [0]  [ 850/1142]  eta: 0:03:31  lr: 0.004256  loss: 0.1441 (0.2108)  loss_classifier: 0.0689 (0.1043)  loss_box_reg: 0.0562 (0.0876)  loss_objectness: 0.0040 (0.0128)  loss_rpn_box_reg: 0.0057 (0.0061)  time: 0.6634  data: 0.0170  max mem: 4904
# Epoch: [0]  [ 860/1142]  eta: 0:03:23  lr: 0.004306  loss: 0.1474 (0.2102)  loss_classifier: 0.0686 (0.1039)  loss_box_reg: 0.0542 (0.0872)  loss_objectness: 0.0065 (0.0129)  loss_rpn_box_reg: 0.0057 (0.0062)  time: 0.6528  data: 0.0164  max mem: 4904
# Epoch: [0]  [ 870/1142]  eta: 0:03:16  lr: 0.004356  loss: 0.1520 (0.2098)  loss_classifier: 0.0686 (0.1037)  loss_box_reg: 0.0637 (0.0871)  loss_objectness: 0.0091 (0.0129)  loss_rpn_box_reg: 0.0035 (0.0062)  time: 0.6313  data: 0.0158  max mem: 4904
# Epoch: [0]  [ 880/1142]  eta: 0:03:08  lr: 0.004406  loss: 0.1394 (0.2091)  loss_classifier: 0.0677 (0.1034)  loss_box_reg: 0.0554 (0.0868)  loss_objectness: 0.0083 (0.0129)  loss_rpn_box_reg: 0.0024 (0.0062)  time: 0.6260  data: 0.0156  max mem: 4904
# Epoch: [0]  [ 890/1142]  eta: 0:03:01  lr: 0.004456  loss: 0.1328 (0.2085)  loss_classifier: 0.0607 (0.1030)  loss_box_reg: 0.0520 (0.0865)  loss_objectness: 0.0059 (0.0129)  loss_rpn_box_reg: 0.0024 (0.0062)  time: 0.7095  data: 0.0165  max mem: 4904
# Epoch: [0]  [ 900/1142]  eta: 0:02:54  lr: 0.004505  loss: 0.1296 (0.2077)  loss_classifier: 0.0566 (0.1025)  loss_box_reg: 0.0500 (0.0861)  loss_objectness: 0.0063 (0.0129)  loss_rpn_box_reg: 0.0022 (0.0062)  time: 0.7564  data: 0.0173  max mem: 4904
# Epoch: [0]  [ 910/1142]  eta: 0:02:47  lr: 0.004555  loss: 0.1296 (0.2074)  loss_classifier: 0.0535 (0.1022)  loss_box_reg: 0.0589 (0.0860)  loss_objectness: 0.0082 (0.0129)  loss_rpn_box_reg: 0.0030 (0.0062)  time: 0.7220  data: 0.0183  max mem: 4904
# Epoch: [0]  [ 920/1142]  eta: 0:02:40  lr: 0.004605  loss: 0.1349 (0.2067)  loss_classifier: 0.0660 (0.1019)  loss_box_reg: 0.0589 (0.0856)  loss_objectness: 0.0102 (0.0130)  loss_rpn_box_reg: 0.0031 (0.0063)  time: 0.7118  data: 0.0192  max mem: 4904
# Epoch: [0]  [ 930/1142]  eta: 0:02:33  lr: 0.004655  loss: 0.1513 (0.2062)  loss_classifier: 0.0660 (0.1016)  loss_box_reg: 0.0554 (0.0854)  loss_objectness: 0.0102 (0.0130)  loss_rpn_box_reg: 0.0023 (0.0062)  time: 0.7220  data: 0.0184  max mem: 4904
# Epoch: [0]  [ 940/1142]  eta: 0:02:25  lr: 0.004705  loss: 0.1622 (0.2058)  loss_classifier: 0.0721 (0.1014)  loss_box_reg: 0.0676 (0.0852)  loss_objectness: 0.0066 (0.0129)  loss_rpn_box_reg: 0.0023 (0.0063)  time: 0.7425  data: 0.0169  max mem: 4904
# Epoch: [0]  [ 950/1142]  eta: 0:02:18  lr: 0.004755  loss: 0.1768 (0.2055)  loss_classifier: 0.0727 (0.1012)  loss_box_reg: 0.0596 (0.0850)  loss_objectness: 0.0052 (0.0129)  loss_rpn_box_reg: 0.0026 (0.0063)  time: 0.7596  data: 0.0163  max mem: 4904
# Epoch: [0]  [ 960/1142]  eta: 0:02:11  lr: 0.004805  loss: 0.1690 (0.2054)  loss_classifier: 0.0720 (0.1011)  loss_box_reg: 0.0582 (0.0849)  loss_objectness: 0.0045 (0.0130)  loss_rpn_box_reg: 0.0042 (0.0064)  time: 0.8378  data: 0.0152  max mem: 4904
# Epoch: [0]  [ 970/1142]  eta: 0:02:04  lr: 0.004855  loss: 0.1486 (0.2047)  loss_classifier: 0.0618 (0.1008)  loss_box_reg: 0.0581 (0.0847)  loss_objectness: 0.0042 (0.0129)  loss_rpn_box_reg: 0.0040 (0.0064)  time: 0.8198  data: 0.0151  max mem: 4904
# Epoch: [0]  [ 980/1142]  eta: 0:01:57  lr: 0.004905  loss: 0.1467 (0.2042)  loss_classifier: 0.0597 (0.1004)  loss_box_reg: 0.0545 (0.0844)  loss_objectness: 0.0043 (0.0129)  loss_rpn_box_reg: 0.0029 (0.0064)  time: 0.6801  data: 0.0173  max mem: 4904
# Epoch: [0]  [ 990/1142]  eta: 0:01:50  lr: 0.004955  loss: 0.1442 (0.2036)  loss_classifier: 0.0623 (0.1001)  loss_box_reg: 0.0513 (0.0842)  loss_objectness: 0.0064 (0.0129)  loss_rpn_box_reg: 0.0043 (0.0064)  time: 0.6948  data: 0.0174  max mem: 4904
# Epoch: [0]  [1000/1142]  eta: 0:01:42  lr: 0.005000  loss: 0.1410 (0.2030)  loss_classifier: 0.0637 (0.0998)  loss_box_reg: 0.0536 (0.0839)  loss_objectness: 0.0063 (0.0129)  loss_rpn_box_reg: 0.0034 (0.0064)  time: 0.7302  data: 0.0179  max mem: 4904
# Epoch: [0]  [1010/1142]  eta: 0:01:35  lr: 0.005000  loss: 0.1528 (0.2027)  loss_classifier: 0.0724 (0.0997)  loss_box_reg: 0.0633 (0.0837)  loss_objectness: 0.0063 (0.0129)  loss_rpn_box_reg: 0.0021 (0.0064)  time: 0.6943  data: 0.0187  max mem: 4904
# Epoch: [0]  [1020/1142]  eta: 0:01:28  lr: 0.005000  loss: 0.1528 (0.2022)  loss_classifier: 0.0814 (0.0995)  loss_box_reg: 0.0550 (0.0834)  loss_objectness: 0.0049 (0.0128)  loss_rpn_box_reg: 0.0031 (0.0064)  time: 0.7677  data: 0.0170  max mem: 4904
# Epoch: [0]  [1030/1142]  eta: 0:01:21  lr: 0.005000  loss: 0.1513 (0.2018)  loss_classifier: 0.0784 (0.0994)  loss_box_reg: 0.0523 (0.0832)  loss_objectness: 0.0054 (0.0128)  loss_rpn_box_reg: 0.0031 (0.0064)  time: 0.7511  data: 0.0167  max mem: 4904
# Epoch: [0]  [1040/1142]  eta: 0:01:13  lr: 0.005000  loss: 0.1374 (0.2013)  loss_classifier: 0.0681 (0.0991)  loss_box_reg: 0.0523 (0.0830)  loss_objectness: 0.0022 (0.0127)  loss_rpn_box_reg: 0.0027 (0.0064)  time: 0.7551  data: 0.0168  max mem: 4904
# Epoch: [0]  [1050/1142]  eta: 0:01:06  lr: 0.005000  loss: 0.1391 (0.2011)  loss_classifier: 0.0713 (0.0990)  loss_box_reg: 0.0528 (0.0829)  loss_objectness: 0.0038 (0.0127)  loss_rpn_box_reg: 0.0028 (0.0064)  time: 0.7515  data: 0.0173  max mem: 4904
# Epoch: [0]  [1060/1142]  eta: 0:00:59  lr: 0.005000  loss: 0.1590 (0.2006)  loss_classifier: 0.0909 (0.0989)  loss_box_reg: 0.0487 (0.0826)  loss_objectness: 0.0080 (0.0127)  loss_rpn_box_reg: 0.0027 (0.0064)  time: 0.6459  data: 0.0181  max mem: 4904
# Epoch: [0]  [1070/1142]  eta: 0:00:52  lr: 0.005000  loss: 0.1381 (0.2001)  loss_classifier: 0.0798 (0.0986)  loss_box_reg: 0.0457 (0.0825)  loss_objectness: 0.0069 (0.0126)  loss_rpn_box_reg: 0.0026 (0.0065)  time: 0.6565  data: 0.0184  max mem: 4904
# Epoch: [0]  [1080/1142]  eta: 0:00:44  lr: 0.005000  loss: 0.1215 (0.1998)  loss_classifier: 0.0612 (0.0984)  loss_box_reg: 0.0529 (0.0823)  loss_objectness: 0.0065 (0.0126)  loss_rpn_box_reg: 0.0036 (0.0065)  time: 0.6815  data: 0.0199  max mem: 4904
# Epoch: [0]  [1090/1142]  eta: 0:00:37  lr: 0.005000  loss: 0.1200 (0.1997)  loss_classifier: 0.0556 (0.0982)  loss_box_reg: 0.0534 (0.0821)  loss_objectness: 0.0050 (0.0128)  loss_rpn_box_reg: 0.0036 (0.0065)  time: 0.6888  data: 0.0199  max mem: 4904
# Epoch: [0]  [1100/1142]  eta: 0:00:30  lr: 0.005000  loss: 0.1255 (0.1993)  loss_classifier: 0.0559 (0.0980)  loss_box_reg: 0.0616 (0.0820)  loss_objectness: 0.0042 (0.0128)  loss_rpn_box_reg: 0.0032 (0.0065)  time: 0.6998  data: 0.0186  max mem: 4904
# Epoch: [0]  [1110/1142]  eta: 0:00:23  lr: 0.005000  loss: 0.1472 (0.1990)  loss_classifier: 0.0732 (0.0979)  loss_box_reg: 0.0570 (0.0819)  loss_objectness: 0.0048 (0.0127)  loss_rpn_box_reg: 0.0032 (0.0065)  time: 0.7077  data: 0.0177  max mem: 4904
# Epoch: [0]  [1120/1142]  eta: 0:00:15  lr: 0.005000  loss: 0.1500 (0.1990)  loss_classifier: 0.0842 (0.0979)  loss_box_reg: 0.0570 (0.0818)  loss_objectness: 0.0077 (0.0128)  loss_rpn_box_reg: 0.0032 (0.0065)  time: 0.7529  data: 0.0168  max mem: 4904
# Epoch: [0]  [1130/1142]  eta: 0:00:08  lr: 0.005000  loss: 0.1819 (0.1988)  loss_classifier: 0.0896 (0.0979)  loss_box_reg: 0.0753 (0.0817)  loss_objectness: 0.0089 (0.0127)  loss_rpn_box_reg: 0.0038 (0.0065)  time: 0.7895  data: 0.0197  max mem: 4904
# Epoch: [0]  [1140/1142]  eta: 0:00:01  lr: 0.005000  loss: 0.1819 (0.1990)  loss_classifier: 0.0896 (0.0980)  loss_box_reg: 0.0623 (0.0816)  loss_objectness: 0.0127 (0.0128)  loss_rpn_box_reg: 0.0042 (0.0066)  time: 0.6964  data: 0.0200  max mem: 4904
# Epoch: [0]  [1141/1142]  eta: 0:00:00  lr: 0.005000  loss: 0.1747 (0.1990)  loss_classifier: 0.0861 (0.0980)  loss_box_reg: 0.0623 (0.0817)  loss_objectness: 0.0127 (0.0128)  loss_rpn_box_reg: 0.0049 (0.0066)  time: 0.6909  data: 0.0194  max mem: 4904
# Epoch: [0] Total time: 0:13:44 (0.7224 s / it)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 151
#     148     lr_scheduler.step()
#     150     # Evaluate on test dataset
# --> 151     evaluate(model, data_loader_test, device=device)
#     153 print("Training completed!")
#     155 # Visualization function
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File d:\Projetos\pythonlib\engine.py:85, in evaluate(model, data_loader, device)
#      82 metric_logger = utils.MetricLogger(delimiter="  ")
#      83 header = "Test:"
# ---> 85 coco = get_coco_api_from_dataset(data_loader.dataset)
#      86 iou_types = _get_iou_types(model)
#      87 coco_evaluator = CocoEvaluator(coco, iou_types)
#
# File d:\Projetos\pythonlib\coco_utils.py:183, in get_coco_api_from_dataset(dataset)
#     181 if isinstance(dataset, torchvision.datasets.CocoDetection):
#     182     return dataset.coco
# --> 183 return convert_to_coco_api(dataset)
#
# File d:\Projetos\pythonlib\coco_utils.py:142, in convert_to_coco_api(ds)
#     140 bboxes = bboxes.tolist()
#     141 labels = targets["labels"].tolist()
# --> 142 areas = targets["area"].tolist()
#     143 iscrowd = targets["iscrowd"].tolist()
#     144 if "masks" in targets:
#
# KeyError: 'area'
